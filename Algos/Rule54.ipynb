# %%
#Libraries
import numpy as np
import pandas as pd
import spacy
import re
import gensim.downloader as api
from gensim.models import KeyedVectors

nlp = spacy.load('en_core_web_md')

# %%
# Importing data into dataframes
gradProgramsJson = "../Data/Gradeo-data/graduateProgrammes.json"
internshipsJson = "../Data/Gradeo-data/internships.json"
vacworkJson = "../Data/Gradeo-data/vacwork.json"

gradProgramsDf = pd.read_json(gradProgramsJson)
internshipsDf = pd.read_json(internshipsJson)
vacworkDf = pd.read_json(vacworkJson)

# %% [markdown]
# ### Helper Functions

# %%
# Dropping all the unnesecary columns => companyLogo; applicationURL; deadline
def coldropper(df):
    df.drop(["companyLogo", "applicationURL", "deadline"], axis=1, inplace=True)

# Remaps all locations in list of dataframes to the provinces. Good for low record volumes
def location_mapper(dflist, location_mapping_dict):
    for i in dflist:
        i["location"] = i["location"].map(location_mapping_dict)

# Gets similar words
def synoget(word_vectors, seed_word):
    synlis = []
    try:
        result = word_vectors.most_similar(positive=[seed_word.lower()])
        for r in result:
            synlis.append(r[0])
    except:
        print("None")
    return synlis

# %% [markdown]
# ### Helper Vars

# %%
word_vectors = api.load("glove-wiki-gigaword-100")

location_mapping_dict = {
    'Addo Elephant National Park':'Eastern Cape',
 'Alberton':"Gauteng",
 'Boksburg':"Gauteng",
 'Bronkhorstspruit':"Gauteng",
 'Cape Town':"Cape Town",
 'Centurion':"Gauteng",
 'Durban':"KwaZulu-Natal",
 'Gauteng':"Gauteng",
 'Germiston':"Gauteng",
 'Hotazel':"Northern Cape",
 'Johannesburg':"Gauteng",
 'Kempton Park':"Gauteng",
 'Kuruman':"Northern Cape",
 'KwaZulu-Natal':"KwaZulu-Natal",
 'Midrand':"Gauteng",
 'Modderfontein':"Gauteng",
 'Mpumalanga':"Mpumalanga",
 'Mulbarton':"Gauteng",
 'Nation wide':"Nationwide",
 'North West':"North West",
 'Polokwane':"Limpopo",
 'Port Elizabeth':"Eastern Cape",
 'Pretoria':"Gauteng",
 'Richards Bay':"KwaZulu-Natal",
 'Roodepoort':"Gauteng",
 'Rustenburg':"North West",
 'Sandton':"Gauteng",
 'Thohoyandou':"Limpopo",
 'Vereeniging':"Gauteng",
 'Weltevredenpark':"Gauteng",
}

# %%
# Dropping unnecessary columns
coldropper(gradProgramsDf)
coldropper(internshipsDf)
coldropper(vacworkDf)

# %%
# Remapping all the locations
location_mapper([gradProgramsDf, internshipsDf, vacworkDf], location_mapping_dict)

# %%
# Combining all dataframes into 1
jobsDf = pd.concat([gradProgramsDf, internshipsDf, vacworkDf], axis=0)

# %%
#Creating seperate columns for each named entity
ner = nlp.pipe_labels['ner']
for i in ner:
    jobsDf[i] = ''

# %%
#NER main
for ind,i in enumerate(jobsDf["description"]):
    try:
        doc = nlp(i)
        for ent in doc.ents:
            jobsDf[ent.label_][ind] = jobsDf[ent.label_][ind] + "," + ent.text
    except:
        pass

# %%
# Only using NERs
collist = ["FAC", "GPE", "ORG", "PERSON", "PRODUCT", "WORK_OF_ART"]
df = pd.DataFrame( columns=collist)
joblist = []

for i in collist:
    for ind, j in enumerate(jobsDf[i]):
        refined = set(str(j).replace("0", "").replace("...\n","").split(","))
        reflist = list(refined)
        filteredls = [element for element in reflist if len(element) >= 3]
        finalstr = ', '.join(filteredls)
        finalstr = re.sub(r'\s+|[()\xa0&]', ' ', finalstr)
        word_list = re.findall(r'[A-Z][a-z]*', finalstr)
        filteredls = [element for element in word_list if len(element) >= 3]
        filteredls = list(set(filteredls))
        finalstr = ', '.join(filteredls)
        joblist.append(finalstr)
    df[i] = joblist
    joblist = []

# %%
# Aggregating all the named entities
df["Agg"] = df["FAC"] + df["GPE"] + df["ORG"] + df["PERSON"] + df["PRODUCT"] + df["WORK_OF_ART"]

# %%
finalDf = jobsDf[["companyName", "jobType", "location", "position", "description"]]
finalDf["Aggregation"] = df["Agg"]
# Out:
# C:\Users\Sachin\AppData\Local\Temp\ipykernel_16692\221068963.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   finalDf["Aggregation"] = df["Agg"]

# %%
##Extended tag generation
finaltagls = []
for ind, i in enumerate(finalDf["Aggregation"]):
    synonym_ls = []
    i = i.replace(" ", "")
    list_tags = i.split(",")
    for i in list_tags:
        synonym_ls.append(i)
        synonym_ls = synonym_ls + synoget(word_vectors, seed_word=i)
    synowords = ', '.join(synonym_ls)
    finaltagls.append(synowords)
    print(synonym_ls)
    print(" ")
# Out:
# None
# None
# ['Africa', 'african', 'continent', 'asia', 'zimbabwe', 'south', 'australia', 'kenya', 'nations', 'africans', 'countries', 'SouthPrograms', 'Eng', 'fra', 'aus', 'capt', 'saracens', 'leicester', 'rsa', 'esp', 'harlequins', '/', 'gareth', 'Must', 'should', 'cannot', 'would', 'need', 'can', 'will', 'not', 'could', 'be', 'come', 'Metals', 'minerals', 'copper', 'commodities', 'ferrous', 'commodity', 'ores', 'aluminium', 'alloys', 'chemicals', 'zinc', 'Professional', 'amateur', 'football', 'career', 'player', 'club', 'players', 'playing', 'team', 'sports', 'basketball', 'Chemical', 'chemicals', 'biological', 'toxic', 'materials', 'biochemical', 'compounds', 'industrial', 'components', 'nuclear', 'pesticides', 'Development', 'projects', 'project', 'developing', 'environment', 'research', 'economic', 'cooperation', 'planning', 'develop', 'creation', 'Completed', 'completion', 'completing', 'complete', 'first', 'construction', 'commenced', 'finished', 'later', 'project', 'prior', 'Mining', 'coal', 'mines', 'copper', 'industrial', 'ore', 'mine', 'mineral', 'exploration', 'minerals', 'logging', 'Engineering', 'sciences', 'technology', 'technical', 'science', 'mechanical', 'engineers', 'institute', 'mathematics', 'biomedical', 'physics', 'Digital', 'electronic', 'analog', 'video', 'audio', 'multimedia', 'computer', 'wireless', 'interactive', 'internet', 'computers', 'Infrastructure', 'infrastructures', 'projects', 'sector', 'development', 'upgrading', 'construction', 'facilities', 'infrastructural', 'services', 'sectors', 'Tertiary', 'secondary', 'schooling', 'post-secondary', 'vocational', 'quaternary', 'colleges', 'undergraduate', 'pupils', 'education', 'university-level', 'InstitutionHatchSelection', 'Graduate', 'undergraduate', 'graduating', 'harvard', 'enrolled', 'graduated', 'college', 'graduates', 'faculty', 'university', 'yale', 'Journey', 'journeys', 'voyage', 'trip', 'travels', 'trek', 'ride', 'adventure', 'path', 'voyages', 'begins']
#
# None
# ['Brands', 'brand', 'products', 'cola', 'cosmetics', 'specialty', 'stores', 'foods', 'drinks', 'marketed', 'beverages', 'Technology', 'technologies', 'computer', 'tech', 'software', 'systems', 'innovation', 'technological', 'engineering', 'research', 'computing', 'Business', 'industry', 'companies', 'businesses', 'marketing', 'company', 'corporate', 'financial', 'market', 'investment', 'management', 'Food', 'foods', 'supplies', 'products', 'meat', 'supply', 'feed', 'medicines', 'meals', 'coffee', 'goods', 'Tiger', 'tigers', 'leopard', 'elephant', 'woods', 'crocodile', 'dragon', 'lion', 'turtle', 'rebel', 'elephants', 'Future', 'possible', 'potential', 'current', 'change', 'our', 'will', 'next', 'would', 'because', 'hope', 'Entrepreneurship', 'innovation', 'entrepreneurial', 'creativity', 'sustainability', 'interdisciplinary', 'empowerment', 'excellence', 'advancement', 'philanthropy', 'fosters', 'Management', 'financial', 'business', 'managers', 'investment', 'development', 'consulting', 'managing', 'marketing', 'corporate', 'asset', 'The', 'this', 'part', 'one', 'of', 'same', 'first', 'on', 'its', 'as', 'that', 'Development', 'projects', 'project', 'developing', 'environment', 'research', 'economic', 'cooperation', 'planning', 'develop', 'creation', 'Degree', 'bachelor', 'doctorate', 'graduate', 'degrees', 'undergraduate', 'graduated', 'ph.d.', 'graduating', 'phd', 'b.a.', 'Economics', 'sociology', 'professor', 'science', 'philosophy', 'psychology', 'mathematics', 'sciences', 'physics', 'harvard', 'institute', 'Leaders', 'politicians', 'ministers', 'urged', 'meeting', 'members', 'allies', 'officials', 'groups', 'parties', 'lawmakers', 'Internship', 'apprenticeship', 'internships', 'sabbatical', 'residencies', 'post-graduate', 'semester', 'undergraduate', 'vocational', 'secretarial', 'part-time', 'Bachelor', 'doctorate', 'degree', 'bachelors', 'graduate', 'ph.d.', 'b.a.', 'undergraduate', 'graduated', 'phd', 'diploma', 'Marketing', 'advertising', 'business', 'merchandising', 'product', 'management', 'corporate', 'brand', 'company', 'strategy', 'creative', 'Programme', 'programmes', 'program', 'programs', 'project', 'bbc', 'development', 'projects', 'funding', 'educational', 'activities', 'Graduate', 'undergraduate', 'graduating', 'harvard', 'enrolled', 'graduated', 'college', 'graduates', 'faculty', 'university', 'yale', 'OpportunitiesGraduate']
#
# ['Business', 'industry', 'companies', 'businesses', 'marketing', 'company', 'corporate', 'financial', 'market', 'investment', 'management', 'Systems', 'system', 'technologies', 'equipment', 'technology', 'software', 'computer', 'devices', 'components', 'communications', 'communication', 'Informatics', 'biomedical', 'neuroscience', 'cybernetics', 'sciences', 'bioinformatics', 'microbiology', 'humanities', 'robotics', 'nanotechnology', 'olympiad', 'Tech', 'technology', 'electronics', 'computer', 'chip', 'big', 'business', 'texas', 'industrial', 'advanced', 'technological', 'Graduates', 'undergraduates', 'graduate', 'students', 'enrolled', 'undergraduate', 'colleges', 'enroll', 'graduating', 'teachers', 'professors', 'Computing', 'computer', 'computational', 'software', 'technology', 'networking', 'desktop', 'automation', 'computation', 'applications', 'systems', 'Sandton', 'suntec', 'randburg', 'johannesburg', 'seatac', 'hillbrow', 'bankstown', 'binhai', 'lanseria', 'cubao', 'manukau', 'Grad', 'bm-21', 'grads', 'mrkonjic', 'mrkonjić', 'katyusha', 'ib', 'rocket', '122mm', 'sipovo', 'rockets', 'Bus', 'train', 'buses', 'commuter', 'taxi', 'passenger', 'truck', 'trains', 'car', 'rail', 'minibus', 'Computer', 'computers', 'software', 'technology', 'pc', 'hardware', 'internet', 'desktop', 'electronic', 'systems', 'computing', 'Commerce', 'trade', 'department', 'transportation', 'tourism', 'finance', 'industry', 'affairs', 'agriculture', 'business', 'bureau', 'Engineering', 'sciences', 'technology', 'technical', 'science', 'mechanical', 'engineers', 'institute', 'mathematics', 'biomedical', 'physics', 'Post', 'office', 'times', 'news', 'end', 'following', 'new', 'time', 'first', 'newspaper', 'recently', 'Information', 'data', 'knowledge', 'access', 'provided', 'intelligence', 'source', 'documents', 'web', 'internet', 'provide', 'Comm', 'graphicsversion', 'usao', 'http://www.nps.gov', 'cpy', 'medlineplus', 'index.php', 'jaraguá', 'p/nea', 'ntags', 'iwin', 'Science', 'sciences', 'physics', 'institute', 'mathematics', 'studies', 'research', 'biology', 'university', 'psychology', 'economics', 'Bachelor', 'doctorate', 'degree', 'bachelors', 'graduate', 'ph.d.', 'b.a.', 'undergraduate', 'graduated', 'phd', 'diploma', 'Investec', 'lereah', 'calyon', 'bittles', 'numis', 'ehrenkrantz', 'ladwa', 'readerman', 'painewebber', 'pecoriello', 'hambrecht', 'Programme', 'programmes', 'program', 'programs', 'project', 'bbc', 'development', 'projects', 'funding', 'educational', 'activities', 'Graduate', 'undergraduate', 'graduating', 'harvard', 'enrolled', 'graduated', 'college', 'graduates', 'faculty', 'university', 'yale']
#
# None
# ['Seek', 'seeking', 'sought', 'seeks', 'allow', 'agree', 'accept', 'to', 'establish', 'bring', 'help', 'ResponsibilitiesQuantitative', 'Applied', 'apply', 'applying', 'application', 'using', 'used', 'obtained', 'applies', 'use', 'applications', 'methods', 'Nedbank', 'cosafa', 'twenty-20', 'vodacom', 'dunhill', 'absa', 'invitational', 'sundarbans', 'canada-russia', 'jeonju', 'everland', 'Financial', 'banking', 'corporate', 'economic', 'credit', 'investment', 'business', 'global', 'management', 'fund', 'banks', 'Contribute', 'contributes', 'encourage', 'reduce', 'benefit', 'promote', 'enhance', 'improve', 'achieve', 'expand', 'accelerate', 'Econometrics', 'climatology', 'criminology', 'econometric', 'geomorphology', 'cybernetics', 'maplewood', 'geology', 'kisco', 'hydrogeology', 'microeconomics', 'Training', 'preparation', 'skills', 'teaching', 'combat', 'program', 'trained', 'instructors', 'personnel', 'operations', 'courses', 'Management', 'financial', 'business', 'managers', 'investment', 'development', 'consulting', 'managing', 'marketing', 'corporate', 'asset', 'Quants', 'b-boys', 'paleoconservatives', 'moscovites', 'rishonim', 'mahatmas', 'objectivists', 'muckrakers', 'maquisards', 'bouchons', 'abelisaurids', 'Risk', 'risks', 'danger', 'exposure', 'potential', 'cause', 'avoid', 'consequences', 'likelihood', 'serious', 'potentially', 'Pure', 'essence', 'true', 'simple', 'organic', 'blend', 'unadulterated', 'purity', 'kind', 'mix', 'passion', 'Mathematics', 'physics', 'mathematical', 'science', 'biology', 'chemistry', 'sociology', 'philosophy', 'humanities', 'linguistics', 'sciences', 'Engineering', 'sciences', 'technology', 'technical', 'science', 'mechanical', 'engineers', 'institute', 'mathematics', 'biomedical', 'physics', 'Programme', 'programmes', 'program', 'programs', 'project', 'bbc', 'development', 'projects', 'funding', 'educational', 'activities']
# ['Informatics', 'biomedical', 'neuroscience', 'cybernetics', 'sciences', 'bioinformatics', 'microbiology', 'humanities', 'robotics', 'nanotechnology', 'olympiad', 'Diploma', 'postgraduate', 'certificate', 'post-graduate', 'diplomas', 'doctorate', 'phd', 'baccalaureate', 'undergraduate', 'doctoral', 'bachelor', 'Eng', 'fra', 'aus', 'capt', 'saracens', 'leicester', 'rsa', 'esp', 'harlequins', '/', 'gareth', 'Science', 'sciences', 'physics', 'institute', 'mathematics', 'studies', 'research', 'biology', 'university', 'psychology', 'economics', 'Continuous', 'constant', 'continual', 'periodic', 'static', 'rapid', 'linear', 'continuation', 'normal', 'extensive', 'direct', 'Honours', 'honors', 'honour', 'bestowed', 'knighthood', 'awarded', 'knighted', 'honorary', 'diploma', 'prizes', 'conferred', 'Software', 'computer', 'hardware', 'microsoft', 'applications', 'technology', 'server', 'user', 'computers', 'desktop', 'web', 'The', 'this', 'part', 'one', 'of', 'same', 'first', 'on', 'its', 'as', 'that', 'Grad', 'bm-21', 'grads', 'mrkonjic', 'mrkonjić', 'katyusha', 'ib', 'rocket', '122mm', 'sipovo', 'rockets', 'Com', 'dot', 'harrynytimes', 'e', 'telegram', 'pager', 'nn', 'coms', 'web', 'berrisnytimes', 'internet', 'Computer', 'computers', 'software', 'technology', 'pc', 'hardware', 'internet', 'desktop', 'electronic', 'systems', 'computing', 'Learning', 'teaching', 'knowledge', 'experience', 'skills', 'learn', 'understanding', 'education', 'educational', 'lessons', 'studying', 'Engineering', 'sciences', 'technology', 'technical', 'science', 'mechanical', 'engineers', 'institute', 'mathematics', 'biomedical', 'physics', 'Programme', 'programmes', 'program', 'programs', 'project', 'bbc', 'development', 'projects', 'funding', 'educational', 'activities', 'Masters', 'pga', 'tournament', 'tennis', 'majors', 'golf', 'tournaments', 'slam', 'championships', 'atp', 'title', 'Bachelors', 'bachelor', 'b.a.', 'ph.d', 'doctorate', 'b.s.', 'ph.d.', 'undergraduate', 'phds', 'laude', 'mba']
#
# ['Team', 'teams', 'squad', 'football', 'players', 'coach', 'player', 'league', 'season', 'soccer', 'championship', 'External', 'internal', 'structural', 'foreign', 'direct', 'and/or', 'current', 'system', 'affairs', 'budgetary', 'input']
#
# None
# None
# ['Africa', 'african', 'continent', 'asia', 'zimbabwe', 'south', 'australia', 'kenya', 'nations', 'africans', 'countries', 'SouthOffice', 'Control', 'controls', 'controlled', 'power', 'controlling', 'system', 'security', 'own', 'authority', 'rule', 'forces', 'Studies', 'study', 'research', 'institute', 'studied', 'science', 'researchers', 'studying', 'scientific', 'university', 'literature', 'Resource', 'resources', 'conservation', 'environment', 'development', 'enterprise', 'natural', 'management', 'energy', 'technology', 'biodiversity', 'Human', 'animal', 'rights', 'humans', 'animals', 'body', 'nature', 'beings', 'organization', 'scientific', 'common', 'Tech', 'technology', 'electronics', 'computer', 'chip', 'big', 'business', 'texas', 'industrial', 'advanced', 'technological', 'Industrial', 'manufacturing', 'industries', 'sector', 'sectors', 'agricultural', 'construction', 'machinery', 'textile', 'industry', 'mining', 'Competencies', 'competences', 'competence', 'competency', 'self-discipline', 'strengths', 'methodologies', 'qualifications', 'teamwork', 'proficiencies', 'abilities', 'Resources', 'resource', 'energy', 'environment', 'development', 'needs', 'natural', 'expertise', 'provide', 'infrastructure', 'reserves', 'Literacy', 'numeracy', 'education', 'educational', 'illiteracy', 'math', 'curriculum', 'proficiency', 'learners', 'awareness', 'enrollment', 'Organisational', 'organizational', 'managerial', 'socio-political', 'societal', 'socio-cultural', 'socio-economic', 'decision-making', 'structural', 'behavioural', 'architectonic', 'Mechanical', 'electrical', 'engineering', 'hydraulic', 'mechanics', 'technical', 'hydraulics', 'physics', 'structural', 'components', 'design', 'Social', 'education', 'political', 'cultural', 'welfare', 'educational', 'reform', 'health', 'public', 'environment', 'environmental', 'Instrumentation', 'acoustic', 'orchestration', 'synthesizers', 'instruments', 'percussion', 'synthesizer', 'instrument', 'keyboards', 'orchestral', 'avionics', 'Completed', 'completion', 'completing', 'complete', 'first', 'construction', 'commenced', 'finished', 'later', 'project', 'prior', 'Sales', 'retail', 'revenue', 'profit', 'earnings', 'consumer', 'profits', 'product', 'revenues', 'market', 'selling', 'Electrical', 'mechanical', 'electric', 'electricity', 'machinery', 'components', 'engineering', 'wiring', 'plumbing', 'equipment', 'generator', 'Management', 'financial', 'business', 'managers', 'investment', 'development', 'consulting', 'managing', 'marketing', 'corporate', 'asset', 'Our', 'their', 'my', 'your', 'own', 'we', 'way', 'what', 'good', 'whatever', 'need', 'Com', 'dot', 'harrynytimes', 'e', 'telegram', 'pager', 'nn', 'coms', 'web', 'berrisnytimes', 'internet', 'Telecommunication', 'telecommunications', 'telecoms', 'telecom', 'communications', 'wireless', 'communication', 'telephony', 'infrastructure', 'services', 'provider', 'Computer', 'computers', 'software', 'technology', 'pc', 'hardware', 'internet', 'desktop', 'electronic', 'systems', 'computing', 'Engineering', 'sciences', 'technology', 'technical', 'science', 'mechanical', 'engineers', 'institute', 'mathematics', 'biomedical', 'physics', 'Labour', 'labor', 'opposition', 'party', 'liberal', 'parliamentary', 'socialist', 'tories', 'mps', 'tory', 'unionist', 'Trainees', 'instructors', 'cadets', 'recruits', 'apprentices', 'sergeants', 'graduates', 'undergraduates', 'tutors', 'interns', 'recruiters', 'Science', 'sciences', 'physics', 'institute', 'mathematics', 'studies', 'research', 'biology', 'university', 'psychology', 'economics', 'Trainee', 'apprentice', 'full-time', 'part-time', 'janitor', 'technician', 'recruiter', 'trainees', 'paralegal', 'instructor', 'tutor', 'Chemical', 'chemicals', 'biological', 'toxic', 'materials', 'biochemical', 'compounds', 'industrial', 'components', 'nuclear', 'pesticides', 'Skills', 'skill', 'abilities', 'talents', 'expertise', 'learning', 'ability', 'knowledge', 'experience', 'talent', 'techniques', 'Marketing', ...
#
# None
# None
# ['StellenboschMust', 'Electrionic', 'Consulting', 'consultant', 'consultancy', 'firm', 'consultants', 'management', 'associates', 'business', 'mckinsey', 'marketing', 'company', 'Graduate', 'undergraduate', 'graduating', 'harvard', 'enrolled', 'graduated', 'college', 'graduates', 'faculty', 'university', 'yale', 'Chemical', 'chemicals', 'biological', 'toxic', 'materials', 'biochemical', 'compounds', 'industrial', 'components', 'nuclear', 'pesticides', 'Industry', 'business', 'companies', 'industries', 'sector', 'company', 'manufacturers', 'firms', 'market', 'makers', 'businesses', 'Wits', 'smarts', 'heartstrings', 'perseverance', 'gnaw', 'headingley', 'loughborough', 'mettle', 'tenacity', 'outwit', 'wit', 'Mining', 'coal', 'mines', 'copper', 'industrial', 'ore', 'mine', 'mineral', 'exploration', 'minerals', 'logging', 'Strategy', 'strategies', 'approach', 'policy', 'plan', 'focus', 'focused', 'aim', 'change', 'tactics', 'marketing', 'Mechanical', 'electrical', 'engineering', 'hydraulic', 'mechanics', 'technical', 'hydraulics', 'physics', 'structural', 'components', 'design', 'Engineering', 'sciences', 'technology', 'technical', 'science', 'mechanical', 'engineers', 'institute', 'mathematics', 'biomedical', 'physics', 'Programme', 'programmes', 'program', 'programs', 'project', 'bbc', 'development', 'projects', 'funding', 'educational', 'activities', 'Electrical', 'mechanical', 'electric', 'electricity', 'machinery', 'components', 'engineering', 'wiring', 'plumbing', 'equipment', 'generator', 'Metallurgical', 'metallurgy', 'petrochemical', 'smelting', 'petrochemicals', 'industrial', 'coking', 'metallurgic', 'plastics', 'engineering', 'coal']
#
# None
# ['Africa', 'african', 'continent', 'asia', 'zimbabwe', 'south', 'australia', 'kenya', 'nations', 'africans', 'countries', 'SouthHuman', 'Business', 'industry', 'companies', 'businesses', 'marketing', 'company', 'corporate', 'financial', 'market', 'investment', 'management', 'Industrial', 'manufacturing', 'industries', 'sector', 'sectors', 'agricultural', 'construction', 'machinery', 'textile', 'industry', 'mining', 'Management', 'financial', 'business', 'managers', 'investment', 'development', 'consulting', 'managing', 'marketing', 'corporate', 'asset', 'Wholesale', 'retail', 'consumer', 'sales', 'prices', 'retailers', 'demand', 'price', 'decline', 'inventories', 'consumption', 'Retail', 'sales', 'retailers', 'consumer', 'stores', 'market', 'retailing', 'wholesale', 'store', 'businesses', 'retailer', 'Administration', 'government', 'policy', 'bush', 'congress', 'officials', 'clinton', 'office', 'department', 'federal', 'washington', 'Education', 'educational', 'schools', 'teaching', 'curriculum', 'programs', 'social', 'health', 'school', 'academic', 'welfare', 'Group', 'groups', 'based', 'members', 'organization', 'led', 'which', 'formed', 'alliance', 'joined', 'called', 'Required', 'require', 'requires', 'requiring', 'necessary', 'requirement', 'requirements', 'allow', 'needed', 'provide', 'must', 'Psychology', 'sociology', 'philosophy', 'anthropology', 'biology', 'psychiatry', 'neuroscience', 'science', 'professor', 'studies', 'economics', 'Marketing', 'advertising', 'business', 'merchandising', 'product', 'management', 'corporate', 'brand', 'company', 'strategy', 'creative', 'Resource', 'resources', 'conservation', 'environment', 'development', 'enterprise', 'natural', 'management', 'energy', 'technology', 'biodiversity', 'Institution', 'institutions', 'society', 'institute', 'established', 'private', 'university', 'foundation', 'academic', 'education', 'educational']
#
# None
# ['Deliver', 'delivering', 'delivered', 'provide', 'carry', 'delivers', 'promised', 'bring', 'send', 'promise', 'produce', 'ResponsibilitiesActuarial', 'Business', 'industry', 'companies', 'businesses', 'marketing', 'company', 'corporate', 'financial', 'market', 'investment', 'management', 'Industrial', 'manufacturing', 'industries', 'sector', 'sectors', 'agricultural', 'construction', 'machinery', 'textile', 'industry', 'mining', 'Science', 'sciences', 'physics', 'institute', 'mathematics', 'studies', 'research', 'biology', 'university', 'psychology', 'economics', 'Finance', 'banking', 'foreign', 'minister', 'financial', 'commerce', 'investment', 'reform', 'government', 'fund', 'affairs', 'Management', 'financial', 'business', 'managers', 'investment', 'development', 'consulting', 'managing', 'marketing', 'corporate', 'asset', 'Systems', 'system', 'technologies', 'equipment', 'technology', 'software', 'computer', 'devices', 'components', 'communications', 'communication', 'Computer', 'computers', 'software', 'technology', 'pc', 'hardware', 'internet', 'desktop', 'electronic', 'systems', 'computing', 'Psychology', 'sociology', 'philosophy', 'anthropology', 'biology', 'psychiatry', 'neuroscience', 'science', 'professor', 'studies', 'economics', 'Information', 'data', 'knowledge', 'access', 'provided', 'intelligence', 'source', 'documents', 'web', 'internet', 'provide']
#
# None
# None
# ['Cape', 'coast', 'island', 'verde', 'isle', 'durban', 'islands', 'south', 'pacific', 'canary', 'ocean', 'Gqeberha', 'Durban', 'johannesburg', 'pretoria', 'bloemfontein', 'pietermaritzburg', 'galle', 'polokwane', 'newlands', 'cape', 'auckland', 'christchurch', 'TownQuantitative', 'Chain', 'chains', 'stores', 'store', 'supermarket', 'grocery', 'retail', 'retailer', 'restaurants', 'shop', 'supermarkets', 'Business', 'industry', 'companies', 'businesses', 'marketing', 'company', 'corporate', 'financial', 'market', 'investment', 'management', 'Management', 'financial', 'business', 'managers', 'investment', 'development', 'consulting', 'managing', 'marketing', 'corporate', 'asset', 'Trade', 'export', 'economic', 'trading', 'commerce', 'cooperation', 'exports', 'industry', 'wto', 'market', 'exchange', 'Shoprite', 'wegmans', 'dfs', 'safeway', 'fujisankei', 'funai', 'takefuji', 'lpga', 'crowne', 'mizuno', 'maurier', 'Leading', 'major', 'led', 'top', 'key', 'among', 'lead', 'third', 'as', 'second', 'both', 'The', 'this', 'part', 'one', 'of', 'same', 'first', 'on', 'its', 'as', 'that', 'Competencies', 'competences', 'competence', 'competency', 'self-discipline', 'strengths', 'methodologies', 'qualifications', 'teamwork', 'proficiencies', 'abilities', 'Supply', 'supplies', 'fuel', 'electricity', 'demand', 'shortage', 'oil', 'capacity', 'food', 'gasoline', 'equipment', 'Group', 'groups', 'based', 'members', 'organization', 'led', 'which', 'formed', 'alliance', 'joined', 'called', 'Skills', 'skill', 'abilities', 'talents', 'expertise', 'learning', 'ability', 'knowledge', 'experience', 'talent', 'techniques', 'Companies', 'firms', 'businesses', 'company', 'corporations', 'industry', 'business', 'manufacturers', 'makers', 'venture', 'industries', 'International', 'european', 'global', 'world', 'nations', 'regional', 'united', 'national', 'for', 'based', 'union']
#
# ['Theory', 'theories', 'concept', 'evolution', 'hypothesis', 'concepts', 'theoretical', 'notion', 'logic', 'philosophy', 'analysis', 'Accounting', 'auditing', 'audit', 'financial', 'auditors', 'practices', 'bookkeeping', 'management', 'corporate', 'disclosure', 'firms']
#
# ['Performance', 'performances', 'best', 'quality', 'success', 'well', 'performing', 'excellent', 'impressive', 'better', 'show', 'Danone', 'nestle', 'aventis', "l'oreal", 'wahaha', 'sanofi', 'inbev', 'pepsico', 'novartis', 'interbrew', 'groupe', 'Operations', 'operation', 'unit', 'operating', 'personnel', 'military', 'services', 'command', 'operational', 'units', 'force']
#
# ['Diploma', 'postgraduate', 'certificate', 'post-graduate', 'diplomas', 'doctorate', 'phd', 'baccalaureate', 'undergraduate', 'doctoral', 'bachelor', 'Bank', 'banks', 'banking', 'credit', 'investment', 'financial', 'securities', 'lending', 'funds', 'ubs', 'finance', 'Accounting', 'auditing', 'audit', 'financial', 'auditors', 'practices', 'bookkeeping', 'management', 'corporate', 'disclosure', 'firms', 'Board', 'commission', 'committee', 'directors', 'executive', 'council', 'panel', 'boards', 'chairman', 'commissioners', 'trustees', 'Theory', 'theories', 'concept', 'evolution', 'hypothesis', 'concepts', 'theoretical', 'notion', 'logic', 'philosophy', 'analysis', 'Postgraduate', 'post-graduate', 'undergraduate', 'diploma', 'doctoral', 'graduate', 'phd', 'courses', 'doctorate', 'ph.d', 'postdoctoral', 'Standard', 'standards', 'basic', 'system', 'definition', 'example', 'same', 'code', 'type', 'use', 'common']
#
# None
# ['AspenDiploma', 'Human', 'animal', 'rights', 'humans', 'animals', 'body', 'nature', 'beings', 'organization', 'scientific', 'common', 'Business', 'industry', 'companies', 'businesses', 'marketing', 'company', 'corporate', 'financial', 'market', 'investment', 'management', 'Science', 'sciences', 'physics', 'institute', 'mathematics', 'studies', 'research', 'biology', 'university', 'psychology', 'economics', 'Capital', 'city', 'central', 'investment', 'government', 'cities', 'outside', 'in', 'bank', 'outskirts', 'northeast', 'Programme', 'programmes', 'program', 'programs', 'project', 'bbc', 'development', 'projects', 'funding', 'educational', 'activities', 'Management', 'financial', 'business', 'managers', 'investment', 'development', 'consulting', 'managing', 'marketing', 'corporate', 'asset', 'Health', 'care', 'medical', 'healthcare', 'education', 'welfare', 'environmental', 'nutrition', 'aids', 'prevention', 'hospitals', 'Competencies', 'competences', 'competence', 'competency', 'self-discipline', 'strengths', 'methodologies', 'qualifications', 'teamwork', 'proficiencies', 'abilities', 'Have', 'they', 'been', 'already', 'could', 'are', 'had', 'not', 'be', 'would', 'still', 'Degree', 'bachelor', 'doctorate', 'graduate', 'degrees', 'undergraduate', 'graduated', 'ph.d.', 'graduating', 'phd', 'b.a.', 'Computer', 'computers', 'software', 'technology', 'pc', 'hardware', 'internet', 'desktop', 'electronic', 'systems', 'computing', 'Skills', 'skill', 'abilities', 'talents', 'expertise', 'learning', 'ability', 'knowledge', 'experience', 'talent', 'techniques', 'Resource', 'resources', 'conservation', 'environment', 'development', 'enterprise', 'natural', 'management', 'energy', 'technology', 'biodiversity', 'Graduate', 'undergraduate', 'graduating', 'harvard', 'enrolled', 'graduated', 'college', 'graduates', 'faculty', 'university', 'yale', 'Internship', 'apprenticeship', 'internships', 'sabbatical', 'residencies', 'post-graduate', 'semester', 'undergraduate', 'vocational', 'secretarial', 'part-time', 'Opportunities', 'opportunity', 'possibilities', 'advantages', 'advantage', 'benefit', 'experience', 'innovation', 'resources', 'development', 'encourage']
# ['Technology', 'technologies', 'computer', 'tech', 'software', 'systems', 'innovation', 'technological', 'engineering', 'research', 'computing', 'Eng', 'fra', 'aus', 'capt', 'saracens', 'leicester', 'rsa', 'esp', 'harlequins', '/', 'gareth', 'Industrial', 'manufacturing', 'industries', 'sector', 'sectors', 'agricultural', 'construction', 'machinery', 'textile', 'industry', 'mining', 'Operations', 'operation', 'unit', 'operating', 'personnel', 'military', 'services', 'command', 'operational', 'units', 'force', 'Trainee', 'apprentice', 'full-time', 'part-time', 'janitor', 'technician', 'recruiter', 'trainees', 'paralegal', 'instructor', 'tutor', 'Opportunties', 'opportunites', 'opportunies', 'legals', 'intiatives', 'propects', 'cost-savings', 'character-building', 'powerplays', 'taskings', 'possibilites', 'Engineer', 'engineers', 'technician', 'mechanic', 'engineering', 'architect', 'contractor', 'officer', 'worked', 'master', 'chemist', 'Bsc', 'hons', 'b.sc', 'phd', 'ph.d', 'm.sc', 'bachelor', 'mphil', 'doctorate', 'b.a.', 'bachelors', 'Mining', 'coal', 'mines', 'copper', 'industrial', 'ore', 'mine', 'mineral', 'exploration', 'minerals', 'logging', 'Mechanical', 'electrical', 'engineering', 'hydraulic', 'mechanics', 'technical', 'hydraulics', 'physics', 'structural', 'components', 'design', 'Engineering', 'sciences', 'technology', 'technical', 'science', 'mechanical', 'engineers', 'institute', 'mathematics', 'biomedical', 'physics', 'Graduate', 'undergraduate', 'graduating', 'harvard', 'enrolled', 'graduated', 'college', 'graduates', 'faculty', 'university', 'yale']
#
# ['Diploma', 'postgraduate', 'certificate', 'post-graduate', 'diplomas', 'doctorate', 'phd', 'baccalaureate', 'undergraduate', 'doctoral', 'bachelor', 'Bank', 'banks', 'banking', 'credit', 'investment', 'financial', 'securities', 'lending', 'funds', 'ubs', 'finance', 'Applied', 'apply', 'applying', 'application', 'using', 'used', 'obtained', 'applies', 'use', 'applications', 'methods', 'Electronic', 'digital', 'computer', 'computerized', 'devices', 'automated', 'technology', 'internet', 'computers', 'systems', 'electronics', 'Science', 'sciences', 'physics', 'institute', 'mathematics', 'studies', 'research', 'biology', 'university', 'psychology', 'economics', 'Accounting', 'auditing', 'audit', 'financial', 'auditors', 'practices', 'bookkeeping', 'management', 'corporate', 'disclosure', 'firms', 'Board', 'commission', 'committee', 'directors', 'executive', 'council', 'panel', 'boards', 'chairman', 'commissioners', 'trustees', 'Theory', 'theories', 'concept', 'evolution', 'hypothesis', 'concepts', 'theoretical', 'notion', 'logic', 'philosophy', 'analysis', 'Postgraduate', 'post-graduate', 'undergraduate', 'diploma', 'doctoral', 'graduate', 'phd', 'courses', 'doctorate', 'ph.d', 'postdoctoral', 'Computer', 'computers', 'software', 'technology', 'pc', 'hardware', 'internet', 'desktop', 'electronic', 'systems', 'computing', 'Mathematics', 'physics', 'mathematical', 'science', 'biology', 'chemistry', 'sociology', 'philosophy', 'humanities', 'linguistics', 'sciences', 'Standard', 'standards', 'basic', 'system', 'definition', 'example', 'same', 'code', 'type', 'use', 'common', 'Engineering', 'sciences', 'technology', 'technical', 'science', 'mechanical', 'engineers', 'institute', 'mathematics', 'biomedical', 'physics', 'Graduate', 'undergraduate', 'graduating', 'harvard', 'enrolled', 'graduated', 'college', 'graduates', 'faculty', 'university', 'yale', 'Internship', 'apprenticeship', 'internships', 'sabbatical', 'residencies', 'post-graduate', 'semester', 'undergraduate', 'vocational', 'secretarial', 'part-time', 'Opportunities', 'opportunity', 'possibilities', 'advantages', 'advantage', 'benefit', 'experience', 'innovation', 'resources', 'development', 'encourage']
#
# None
# ['Terminals', 'ports', 'terminal', 'airports', 'container', 'docks', 'shipping', 'seaports', 'tankers', 'heathrow', 'pipelines', 'Port', 'ports', 'coast', 'city', 'ship', 'harbour', 'coastal', 'airport', 'shipping', 'seaport', 'terminal', 'TransnetAudit', 'Office', 'offices', 'house', 'department', 'administration', 'post', 'government', 'public', 'official', 'officials', 'headquarters', 'Training', 'preparation', 'skills', 'teaching', 'combat', 'program', 'trained', 'instructors', 'personnel', 'operations', 'courses', 'General', 'secretary', 'chief', 'gen.', 'president', 'vice', 'office', 'deputy', 'department', 'commander', 'led', 'Professional', 'amateur', 'football', 'career', 'player', 'club', 'players', 'playing', 'team', 'sports', 'basketball', 'Time', 'when', 'this', 'before', 'but', 'only', 'one', '.', 'same', 'first', 'days', 'Accounting', 'auditing', 'audit', 'financial', 'auditors', 'practices', 'bookkeeping', 'management', 'corporate', 'disclosure', 'firms', 'Internal', 'external', 'ongoing', 'security', 'problems', 'investigations', 'control', 'political', 'investigation', 'current', 'source', 'Competencies', 'competences', 'competence', 'competency', 'self-discipline', 'strengths', 'methodologies', 'qualifications', 'teamwork', 'proficiencies', 'abilities', 'Skills', 'skill', 'abilities', 'talents', 'expertise', 'learning', 'ability', 'knowledge', 'experience', 'talent', 'techniques', 'Programme', 'programmes', 'program', 'programs', 'project', 'bbc', 'development', 'projects', 'funding', 'educational', 'activities', 'Young', 'younger', 'fellow', 'man', 'children', 'boys', 'talented', 'girls', 'teenage', 'child', 'youngsters']
#
# ['Treasury', 'bond', 'finance', 'bonds', 'yields', 'geithner', 'federal', 'greenspan', 'funds', 'securities', 'borrowing', 'Technology', 'technologies', 'computer', 'tech', 'software', 'systems', 'innovation', 'technological', 'engineering', 'research', 'computing', 'Relations', 'ties', 'cooperation', 'relationship', 'bilateral', 'diplomatic', 'friendship', 'contacts', 'dialogue', 'strengthen', 'political', 'Point', 'points', 'one', 'time', 'just', 'close', 'this', 'only', 'same', 'difference', 'end', 'Financial', 'banking', 'corporate', 'economic', 'credit', 'investment', 'business', 'global', 'management', 'fund', 'banks', 'Econometrics', 'climatology', 'criminology', 'econometric', 'geomorphology', 'cybernetics', 'maplewood', 'geology', 'kisco', 'hydrogeology', 'microeconomics', 'Analysis', 'analyses', 'data', 'research', 'study', 'methods', 'scientific', 'methodology', 'assessment', 'studies', 'theory', 'Management', 'financial', 'business', 'managers', 'investment', 'development', 'consulting', 'managing', 'marketing', 'corporate', 'asset', 'Office', 'offices', 'house', 'department', 'administration', 'post', 'government', 'public', 'official', 'officials', 'headquarters', 'Power', 'control', 'electricity', 'powers', 'energy', 'over', 'pressure', 'system', 'turn', 'government', 'bring', 'Head', 'heads', 'headed', 'chief', 'body', 'assistant', 'chair', 'hand', 'former', 'senior', 'hands', 'Project', 'projects', 'development', 'program', 'plan', 'construction', 'plans', 'work', 'initiative', 'part', 'build', 'Academy', 'arts', 'school', 'institute', 'college', 'sciences', 'university', 'graduate', 'science', 'graduating', 'graduated', 'Information', 'data', 'knowledge', 'access', 'provided', 'intelligence', 'source', 'documents', 'web', 'internet', 'provide', 'International', 'european', 'global', 'world', 'nations', 'regional', 'united', 'national', 'for', 'based', 'union', 'Policy', 'policies', 'administration', 'reform', 'strategy', 'economic', 'issue', 'agenda', 'approach', 'change', 'stance']
#
# None
# None
# None
# ['Quantitative', 'qualitative', 'empirical', 'analysis', 'methodology', 'analytical', 'methods', 'analyses', 'behavioral', 'descriptive', 'theoretical', 'Technology', 'technologies', 'computer', 'tech', 'software', 'systems', 'innovation', 'technological', 'engineering', 'research', 'computing', 'Financial', 'banking', 'corporate', 'economic', 'credit', 'investment', 'business', 'global', 'management', 'fund', 'banks', 'Sciences', 'science', 'institute', 'humanities', 'engineering', 'physics', 'biology', 'chemistry', 'mathematics', 'academy', 'arts', 'Governance', 'transparency', 'accountability', 'sustainability', 'management', 'reform', 'framework', 'reforms', 'stability', 'macroeconomic', 'policies', 'Services', 'service', 'transportation', 'communications', 'business', 'access', 'communication', 'provider', 'private', 'providers', 'public', 'Systems', 'system', 'technologies', 'equipment', 'technology', 'software', 'computer', 'devices', 'components', 'communications', 'communication', 'Specialsed', 'Advisory', 'committee', 'panel', 'commission', 'board', 'review', 'recommendations', 'committees', 'council', 'recommendation', 'expert', 'Tax', 'taxes', 'income', 'spending', 'savings', 'costs', 'money', 'budget', 'federal', 'cuts', 'payments', 'Applied', 'apply', 'applying', 'application', 'using', 'used', 'obtained', 'applies', 'use', 'applications', 'methods', 'Electronic', 'digital', 'computer', 'computerized', 'devices', 'automated', 'technology', 'internet', 'computers', 'systems', 'electronics', 'Industrial', 'manufacturing', 'industries', 'sector', 'sectors', 'agricultural', 'construction', 'machinery', 'textile', 'industry', 'mining', 'Geography', 'sociology', 'geology', 'mathematics', 'anthropology', 'biology', 'philosophy', 'economics', 'demography', 'ecology', 'linguistics', 'Forensic', 'forensics', 'pathologist', 'investigator', 'examination', 'pathologists', 'investigators', 'examined', 'ballistics', 'detectives', 'expert', 'Deloittian', 'Law', 'laws', 'legal', 'rules', 'constitutional', 'act', 'federal', 'legislation', 'statute', 'court', 'regulations', 'Risk', 'risks', 'danger', 'exposure', 'potential', 'cause', 'avoid', 'consequences', 'likelihood', 'serious', 'potentially', 'Bsc', 'hons', 'b.sc', 'phd', 'ph.d', 'm.sc', 'bachelor', 'mphil', 'doctorate', 'b.a.', 'bachelors', 'Social', 'education', 'political', 'cultural', 'welfare', 'educational', 'reform', 'health', 'public', 'environment', 'environmental', 'Mathematical', 'theoretical', 'computational', 'mathematics', 'physics', 'equations', 'computation', 'empirical', 'theory', 'numerical', 'geometry', 'Sustainability', 'sustainable', 'governance', 'innovation', 'environmental', 'ecological', 'entrepreneurship', 'biodiversity', 'competitiveness', 'conservation', 'excellence', 'Completed', 'completion', 'completing', 'complete', 'first', 'construction', 'commenced', 'finished', 'later', 'project', 'prior', 'Electrical', 'mechanical', 'electric', 'electricity', 'machinery', 'components', 'engineering', 'wiring', 'plumbing', 'equipment', 'generator', 'Crime', 'criminal', 'crimes', 'murder', 'trafficking', 'terrorism', 'homicide', 'corruption', 'criminals', 'gang', 'dealing', 'Actuarial', 'accountancy', 'astronomical', 'obstetrical', 'inexact', 'mathematical', 'macroeconomics', 'actuary', 'empirical', 'informatics', 'anthropological', 'Data', 'information', 'analysis', 'tracking', 'database', 'system', 'computer', 'statistics', 'systems', 'applications', 'numbers', 'Relevant', 'appropriate', 'specific', 'aspects', 'pertinent', 'applicable', 'matters', 'concerning', 'certain', 'important', 'regarding', 'Management', 'financial', 'business', 'managers', 'investment', 'development', 'consulting', 'managing', 'marketing', 'corporate', 'asset', 'Opportunities', 'opportunity', 'possibilities', 'advantages', 'advantage', 'benefit', 'experience', 'innovation', 'resources', 'development', 'encourage', 'Com', 'dot', 'harrynytimes', 'e', 'telegram', 'pager', 'nn', 'coms', ...
# ['Science', 'sciences', 'physics', 'institute', 'mathematics', 'studies', 'research', 'biology', 'university', 'psychology', 'economics', 'Develop', 'developing', 'build', 'create', 'expand', 'improve', 'promote', 'establish', 'enhance', 'developed', 'provide', 'Export', 'import', 'exports', 'imports', 'goods', 'exporting', 'trade', 'output', 'demand', 'products', 'imported', 'Import', 'export', 'imports', 'exports', 'imported', 'tariffs', 'goods', 'importing', 'tariff', 'importation', 'quotas', 'Communication', 'communications', 'systems', 'services', 'technology', 'knowledge', 'information', 'learning', 'interaction', 'navigation', 'connections', 'Internal', 'external', 'ongoing', 'security', 'problems', 'investigations', 'control', 'political', 'investigation', 'current', 'source', 'Cleansing', 'massacres', 'genocide', 'atrocities', 'bloodletting', 'extermination', 'genocidal', 'repression', 'systematic', 'albanians', 'ritual', 'Computer', 'computers', 'software', 'technology', 'pc', 'hardware', 'internet', 'desktop', 'electronic', 'systems', 'computing', 'External', 'internal', 'structural', 'foreign', 'direct', 'and/or', 'current', 'system', 'affairs', 'budgetary', 'input', 'Data', 'information', 'analysis', 'tracking', 'database', 'system', 'computer', 'statistics', 'systems', 'applications', 'numbers']
#
# None
# ['Gauteng', 'kwazulu-natal', 'mpumalanga', 'transvaal', 'copperbelt', 'limpopo', 'masvingo', 'manicaland', 'toowoomba', 'natal', 'guangdong', 'JohannesburgTechnology', 'Financial', 'banking', 'corporate', 'economic', 'credit', 'investment', 'business', 'global', 'management', 'fund', 'banks', 'Sciences', 'science', 'institute', 'humanities', 'engineering', 'physics', 'biology', 'chemistry', 'mathematics', 'academy', 'arts', 'Dimension', 'dimensions', 'element', 'dimensional', 'complexity', 'sphere', 'context', 'spatial', 'aspect', 'definition', 'infinite', 'Services', 'service', 'transportation', 'communications', 'business', 'access', 'communication', 'provider', 'private', 'providers', 'public', 'Systems', 'system', 'technologies', 'equipment', 'technology', 'software', 'computer', 'devices', 'components', 'communications', 'communication', 'Chain', 'chains', 'stores', 'store', 'supermarket', 'grocery', 'retail', 'retailer', 'restaurants', 'shop', 'supermarkets', 'Eng', 'fra', 'aus', 'capt', 'saracens', 'leicester', 'rsa', 'esp', 'harlequins', '/', 'gareth', 'Industrial', 'manufacturing', 'industries', 'sector', 'sectors', 'agricultural', 'construction', 'machinery', 'textile', 'industry', 'mining', 'Chartered', 'airline', 'operated', 'airlines', 'charter', 'boarded', 'aboard', 'flight', 'carrier', 'hijacked', 'flying', 'Risk', 'risks', 'danger', 'exposure', 'potential', 'cause', 'avoid', 'consequences', 'likelihood', 'serious', 'potentially', 'Supply', 'supplies', 'fuel', 'electricity', 'demand', 'shortage', 'oil', 'capacity', 'food', 'gasoline', 'equipment', 'Management', 'financial', 'business', 'managers', 'investment', 'development', 'consulting', 'managing', 'marketing', 'corporate', 'asset', 'Computer', 'computers', 'software', 'technology', 'pc', 'hardware', 'internet', 'desktop', 'electronic', 'systems', 'computing', 'Information', 'data', 'knowledge', 'access', 'provided', 'intelligence', 'source', 'documents', 'web', 'internet', 'provide', 'Applications', 'application', 'software', 'systems', 'users', 'available', 'computer', 'processing', 'technology', 'data', 'computing', 'Science', 'sciences', 'physics', 'institute', 'mathematics', 'studies', 'research', 'biology', 'university', 'psychology', 'economics', 'Accounting', 'auditing', 'audit', 'financial', 'auditors', 'practices', 'bookkeeping', 'management', 'corporate', 'disclosure', 'firms', 'Accountancy', 'auditing', 'actuarial', 'accountants', 'deloitte', 'pricewaterhousecoopers', 'profession', 'self-financing', 'accounting', 'professions', 'm.b.a.', 'Data', 'information', 'analysis', 'tracking', 'database', 'system', 'computer', 'statistics', 'systems', 'applications', 'numbers']
#
# None
# None
# ['Town', 'village', 'city', 'near', 'towns', 'area', 'nearby', 'northern', 'where', 'southern', 'west', 'Centurion', 'kingsmead', 'headingley', 'supersport', 'edgbaston', 'gabba', 'bloemfontein', 'scoreboard', 'newlands', 'dayer', 'odi', 'Durban', 'johannesburg', 'pretoria', 'bloemfontein', 'pietermaritzburg', 'galle', 'polokwane', 'newlands', 'cape', 'auckland', 'christchurch', 'Gqeberha', 'CapeQuantitative', 'Chain', 'chains', 'stores', 'store', 'supermarket', 'grocery', 'retail', 'retailer', 'restaurants', 'shop', 'supermarkets', 'Business', 'industry', 'companies', 'businesses', 'marketing', 'company', 'corporate', 'financial', 'market', 'investment', 'management', 'Management', 'financial', 'business', 'managers', 'investment', 'development', 'consulting', 'managing', 'marketing', 'corporate', 'asset', 'Strong', 'stronger', 'despite', 'weak', 'solid', 'very', 'strongest', 'good', 'strength', 'particularly', 'robust', 'Trade', 'export', 'economic', 'trading', 'commerce', 'cooperation', 'exports', 'industry', 'wto', 'market', 'exchange', 'Shoprite', 'wegmans', 'dfs', 'safeway', 'fujisankei', 'funai', 'takefuji', 'lpga', 'crowne', 'mizuno', 'maurier', 'Competencies', 'competences', 'competence', 'competency', 'self-discipline', 'strengths', 'methodologies', 'qualifications', 'teamwork', 'proficiencies', 'abilities', 'The', 'this', 'part', 'one', 'of', 'same', 'first', 'on', 'its', 'as', 'that', 'Supply', 'supplies', 'fuel', 'electricity', 'demand', 'shortage', 'oil', 'capacity', 'food', 'gasoline', 'equipment', 'Group', 'groups', 'based', 'members', 'organization', 'led', 'which', 'formed', 'alliance', 'joined', 'called', 'Skills', 'skill', 'abilities', 'talents', 'expertise', 'learning', 'ability', 'knowledge', 'experience', 'talent', 'techniques', 'Companies', 'firms', 'businesses', 'company', 'corporations', 'industry', 'business', 'manufacturers', 'makers', 'venture', 'industries', 'Interpersonal', 'intrapersonal', 'intimacy', 'interaction', 'interactions', 'cross-cultural', 'communicative', 'relationships', 'socialization', 'cognitive', 'perceptual', 'International', 'european', 'global', 'world', 'nations', 'regional', 'united', 'national', 'for', 'based', 'union']
#
# ['Motor', 'automobile', 'motors', 'auto', 'electric', 'toyota', 'honda', 'automaker', 'nissan', 'racing', 'vehicle', 'Processes', 'mechanisms', 'process', 'methods', 'processing', 'techniques', 'functions', 'and/or', 'mechanism', 'components', 'systems', 'Contribute', 'contributes', 'encourage', 'reduce', 'benefit', 'promote', 'enhance', 'improve', 'achieve', 'expand', 'accelerate', 'Procedures', 'procedure', 'requirements', 'guidelines', 'regulations', 'required', 'rules', 'methods', 'practices', 'require', 'necessary', 'Management', 'financial', 'business', 'managers', 'investment', 'development', 'consulting', 'managing', 'marketing', 'corporate', 'asset', 'Accident', 'crash', 'collision', 'accidents', 'mishap', 'explosion', 'fatal', 'incident', 'crashes', 'occurred', 'blast', 'Develop', 'developing', 'build', 'create', 'expand', 'improve', 'promote', 'establish', 'enhance', 'developed', 'provide', 'Power', 'control', 'electricity', 'powers', 'energy', 'over', 'pressure', 'system', 'turn', 'government', 'bring', 'Python', 'monty', 'php', 'perl', 'cleese', 'flipper', 'ruby', 'spamalot', 'javascript', 'reticulated', 'monkey', 'Microsoft', 'google', 'netscape', 'ibm', 'intel', 'software', 'yahoo', 'apple', 'aol', 'compaq', 'oracle', 'Systems', 'system', 'technologies', 'equipment', 'technology', 'software', 'computer', 'devices', 'components', 'communications', 'communication', 'Mining', 'coal', 'mines', 'copper', 'industrial', 'ore', 'mine', 'mineral', 'exploration', 'minerals', 'logging', 'Products', 'product', 'goods', 'manufacturers', 'imported', 'foods', 'packaging', 'food', 'materials', 'sales', 'brands', 'Application', 'applications', 'user', 'software', 'allows', 'applied', 'interface', 'file', 'functionality', 'system', 'apply', 'Vehicle', 'car', 'vehicles', 'truck', 'cars', 'suv', 'driving', 'driver', 'jeep', 'trucks', 'parked', 'Data', 'information', 'analysis', 'tracking', 'database', 'system', 'computer', 'statistics', 'systems', 'applications', 'numbers']
# ...
#
# None
# ['Seek', 'seeking', 'sought', 'seeks', 'allow', 'agree', 'accept', 'to', 'establish', 'bring', 'help', 'ResponsibilitiesQuantitative', 'Applied', 'apply', 'applying', 'application', 'using', 'used', 'obtained', 'applies', 'use', 'applications', 'methods', 'Nedbank', 'cosafa', 'twenty-20', 'vodacom', 'dunhill', 'absa', 'invitational', 'sundarbans', 'canada-russia', 'jeonju', 'everland', 'Financial', 'banking', 'corporate', 'economic', 'credit', 'investment', 'business', 'global', 'management', 'fund', 'banks', 'Contribute', 'contributes', 'encourage', 'reduce', 'benefit', 'promote', 'enhance', 'improve', 'achieve', 'expand', 'accelerate', 'Econometrics', 'climatology', 'criminology', 'econometric', 'geomorphology', 'cybernetics', 'maplewood', 'geology', 'kisco', 'hydrogeology', 'microeconomics', 'Training', 'preparation', 'skills', 'teaching', 'combat', 'program', 'trained', 'instructors', 'personnel', 'operations', 'courses', 'Management', 'financial', 'business', 'managers', 'investment', 'development', 'consulting', 'managing', 'marketing', 'corporate', 'asset', 'Quants', 'b-boys', 'paleoconservatives', 'moscovites', 'rishonim', 'mahatmas', 'objectivists', 'muckrakers', 'maquisards', 'bouchons', 'abelisaurids', 'Risk', 'risks', 'danger', 'exposure', 'potential', 'cause', 'avoid', 'consequences', 'likelihood', 'serious', 'potentially', 'Pure', 'essence', 'true', 'simple', 'organic', 'blend', 'unadulterated', 'purity', 'kind', 'mix', 'passion', 'Mathematics', 'physics', 'mathematical', 'science', 'biology', 'chemistry', 'sociology', 'philosophy', 'humanities', 'linguistics', 'sciences', 'Engineering', 'sciences', 'technology', 'technical', 'science', 'mechanical', 'engineers', 'institute', 'mathematics', 'biomedical', 'physics', 'Programme', 'programmes', 'program', 'programs', 'project', 'bbc', 'development', 'projects', 'funding', 'educational', 'activities']
# ['Informatics', 'biomedical', 'neuroscience', 'cybernetics', 'sciences', 'bioinformatics', 'microbiology', 'humanities', 'robotics', 'nanotechnology', 'olympiad', 'Diploma', 'postgraduate', 'certificate', 'post-graduate', 'diplomas', 'doctorate', 'phd', 'baccalaureate', 'undergraduate', 'doctoral', 'bachelor', 'Eng', 'fra', 'aus', 'capt', 'saracens', 'leicester', 'rsa', 'esp', 'harlequins', '/', 'gareth', 'Science', 'sciences', 'physics', 'institute', 'mathematics', 'studies', 'research', 'biology', 'university', 'psychology', 'economics', 'Continuous', 'constant', 'continual', 'periodic', 'static', 'rapid', 'linear', 'continuation', 'normal', 'extensive', 'direct', 'Honours', 'honors', 'honour', 'bestowed', 'knighthood', 'awarded', 'knighted', 'honorary', 'diploma', 'prizes', 'conferred', 'Software', 'computer', 'hardware', 'microsoft', 'applications', 'technology', 'server', 'user', 'computers', 'desktop', 'web', 'The', 'this', 'part', 'one', 'of', 'same', 'first', 'on', 'its', 'as', 'that', 'Grad', 'bm-21', 'grads', 'mrkonjic', 'mrkonjić', 'katyusha', 'ib', 'rocket', '122mm', 'sipovo', 'rockets', 'Com', 'dot', 'harrynytimes', 'e', 'telegram', 'pager', 'nn', 'coms', 'web', 'berrisnytimes', 'internet', 'Computer', 'computers', 'software', 'technology', 'pc', 'hardware', 'internet', 'desktop', 'electronic', 'systems', 'computing', 'Learning', 'teaching', 'knowledge', 'experience', 'skills', 'learn', 'understanding', 'education', 'educational', 'lessons', 'studying', 'Engineering', 'sciences', 'technology', 'technical', 'science', 'mechanical', 'engineers', 'institute', 'mathematics', 'biomedical', 'physics', 'Programme', 'programmes', 'program', 'programs', 'project', 'bbc', 'development', 'projects', 'funding', 'educational', 'activities', 'Masters', 'pga', 'tournament', 'tennis', 'majors', 'golf', 'tournaments', 'slam', 'championships', 'atp', 'title', 'Bachelors', 'bachelor', 'b.a.', 'ph.d', 'doctorate', 'b.s.', 'ph.d.', 'undergraduate', 'phds', 'laude', 'mba']
#
# ['Team', 'teams', 'squad', 'football', 'players', 'coach', 'player', 'league', 'season', 'soccer', 'championship', 'External', 'internal', 'structural', 'foreign', 'direct', 'and/or', 'current', 'system', 'affairs', 'budgetary', 'input']
#
# None
# None
# ['Africa', 'african', 'continent', 'asia', 'zimbabwe', 'south', 'australia', 'kenya', 'nations', 'africans', 'countries', 'SouthOffice', 'Control', 'controls', 'controlled', 'power', 'controlling', 'system', 'security', 'own', 'authority', 'rule', 'forces', 'Studies', 'study', 'research', 'institute', 'studied', 'science', 'researchers', 'studying', 'scientific', 'university', 'literature', 'Resource', 'resources', 'conservation', 'environment', 'development', 'enterprise', 'natural', 'management', 'energy', 'technology', 'biodiversity', 'Human', 'animal', 'rights', 'humans', 'animals', 'body', 'nature', 'beings', 'organization', 'scientific', 'common', 'Tech', 'technology', 'electronics', 'computer', 'chip', 'big', 'business', 'texas', 'industrial', 'advanced', 'technological', 'Industrial', 'manufacturing', 'industries', 'sector', 'sectors', 'agricultural', 'construction', 'machinery', 'textile', 'industry', 'mining', 'Competencies', 'competences', 'competence', 'competency', 'self-discipline', 'strengths', 'methodologies', 'qualifications', 'teamwork', 'proficiencies', 'abilities', 'Resources', 'resource', 'energy', 'environment', 'development', 'needs', 'natural', 'expertise', 'provide', 'infrastructure', 'reserves', 'Literacy', 'numeracy', 'education', 'educational', 'illiteracy', 'math', 'curriculum', 'proficiency', 'learners', 'awareness', 'enrollment', 'Organisational', 'organizational', 'managerial', 'socio-political', 'societal', 'socio-cultural', 'socio-economic', 'decision-making', 'structural', 'behavioural', 'architectonic', 'Mechanical', 'electrical', 'engineering', 'hydraulic', 'mechanics', 'technical', 'hydraulics', 'physics', 'structural', 'components', 'design', 'Social', 'education', 'political', 'cultural', 'welfare', 'educational', 'reform', 'health', 'public', 'environment', 'environmental', 'Instrumentation', 'acoustic', 'orchestration', 'synthesizers', 'instruments', 'percussion', 'synthesizer', 'instrument', 'keyboards', 'orchestral', 'avionics', 'Completed', 'completion', 'completing', 'complete', 'first', 'construction', 'commenced', 'finished', 'later', 'project', 'prior', 'Sales', 'retail', 'revenue', 'profit', 'earnings', 'consumer', 'profits', 'product', 'revenues', 'market', 'selling', 'Electrical', 'mechanical', 'electric', 'electricity', 'machinery', 'components', 'engineering', 'wiring', 'plumbing', 'equipment', 'generator', 'Management', 'financial', 'business', 'managers', 'investment', 'development', 'consulting', 'managing', 'marketing', 'corporate', 'asset', 'Our', 'their', 'my', 'your', 'own', 'we', 'way', 'what', 'good', 'whatever', 'need', 'Com', 'dot', 'harrynytimes', 'e', 'telegram', 'pager', 'nn', 'coms', 'web', 'berrisnytimes', 'internet', 'Telecommunication', 'telecommunications', 'telecoms', 'telecom', 'communications', 'wireless', 'communication', 'telephony', 'infrastructure', 'services', 'provider', 'Computer', 'computers', 'software', 'technology', 'pc', 'hardware', 'internet', 'desktop', 'electronic', 'systems', 'computing', 'Engineering', 'sciences', 'technology', 'technical', 'science', 'mechanical', 'engineers', 'institute', 'mathematics', 'biomedical', 'physics', 'Labour', 'labor', 'opposition', 'party', 'liberal', 'parliamentary', 'socialist', 'tories', 'mps', 'tory', 'unionist', 'Trainees', 'instructors', 'cadets', 'recruits', 'apprentices', 'sergeants', 'graduates', 'undergraduates', 'tutors', 'interns', 'recruiters', 'Science', 'sciences', 'physics', 'institute', 'mathematics', 'studies', 'research', 'biology', 'university', 'psychology', 'economics', 'Trainee', 'apprentice', 'full-time', 'part-time', 'janitor', 'technician', 'recruiter', 'trainees', 'paralegal', 'instructor', 'tutor', 'Chemical', 'chemicals', 'biological', 'toxic', 'materials', 'biochemical', 'compounds', 'industrial', 'components', 'nuclear', 'pesticides', 'Skills', 'skill', 'abilities', 'talents', 'expertise', 'learning', 'ability', 'knowledge', 'experience', 'talent', 'techniques', 'Marketing', ...
#
# None
# None
# ['StellenboschMust', 'Electrionic', 'Consulting', 'consultant', 'consultancy', 'firm', 'consultants', 'management', 'associates', 'business', 'mckinsey', 'marketing', 'company', 'Graduate', 'undergraduate', 'graduating', 'harvard', 'enrolled', 'graduated', 'college', 'graduates', 'faculty', 'university', 'yale', 'Chemical', 'chemicals', 'biological', 'toxic', 'materials', 'biochemical', 'compounds', 'industrial', 'components', 'nuclear', 'pesticides', 'Industry', 'business', 'companies', 'industries', 'sector', 'company', 'manufacturers', 'firms', 'market', 'makers', 'businesses', 'Wits', 'smarts', 'heartstrings', 'perseverance', 'gnaw', 'headingley', 'loughborough', 'mettle', 'tenacity', 'outwit', 'wit', 'Mining', 'coal', 'mines', 'copper', 'industrial', 'ore', 'mine', 'mineral', 'exploration', 'minerals', 'logging', 'Strategy', 'strategies', 'approach', 'policy', 'plan', 'focus', 'focused', 'aim', 'change', 'tactics', 'marketing', 'Mechanical', 'electrical', 'engineering', 'hydraulic', 'mechanics', 'technical', 'hydraulics', 'physics', 'structural', 'components', 'design', 'Engineering', 'sciences', 'technology', 'technical', 'science', 'mechanical', 'engineers', 'institute', 'mathematics', 'biomedical', 'physics', 'Programme', 'programmes', 'program', 'programs', 'project', 'bbc', 'development', 'projects', 'funding', 'educational', 'activities', 'Electrical', 'mechanical', 'electric', 'electricity', 'machinery', 'components', 'engineering', 'wiring', 'plumbing', 'equipment', 'generator', 'Metallurgical', 'metallurgy', 'petrochemical', 'smelting', 'petrochemicals', 'industrial', 'coking', 'metallurgic', 'plastics', 'engineering', 'coal']
#
# None
# ['Africa', 'african', 'continent', 'asia', 'zimbabwe', 'south', 'australia', 'kenya', 'nations', 'africans', 'countries', 'SouthHuman', 'Business', 'industry', 'companies', 'businesses', 'marketing', 'company', 'corporate', 'financial', 'market', 'investment', 'management', 'Industrial', 'manufacturing', 'industries', 'sector', 'sectors', 'agricultural', 'construction', 'machinery', 'textile', 'industry', 'mining', 'Management', 'financial', 'business', 'managers', 'investment', 'development', 'consulting', 'managing', 'marketing', 'corporate', 'asset', 'Wholesale', 'retail', 'consumer', 'sales', 'prices', 'retailers', 'demand', 'price', 'decline', 'inventories', 'consumption', 'Retail', 'sales', 'retailers', 'consumer', 'stores', 'market', 'retailing', 'wholesale', 'store', 'businesses', 'retailer', 'Administration', 'government', 'policy', 'bush', 'congress', 'officials', 'clinton', 'office', 'department', 'federal', 'washington', 'Education', 'educational', 'schools', 'teaching', 'curriculum', 'programs', 'social', 'health', 'school', 'academic', 'welfare', 'Group', 'groups', 'based', 'members', 'organization', 'led', 'which', 'formed', 'alliance', 'joined', 'called', 'Required', 'require', 'requires', 'requiring', 'necessary', 'requirement', 'requirements', 'allow', 'needed', 'provide', 'must', 'Psychology', 'sociology', 'philosophy', 'anthropology', 'biology', 'psychiatry', 'neuroscience', 'science', 'professor', 'studies', 'economics', 'Marketing', 'advertising', 'business', 'merchandising', 'product', 'management', 'corporate', 'brand', 'company', 'strategy', 'creative', 'Resource', 'resources', 'conservation', 'environment', 'development', 'enterprise', 'natural', 'management', 'energy', 'technology', 'biodiversity', 'Institution', 'institutions', 'society', 'institute', 'established', 'private', 'university', 'foundation', 'academic', 'education', 'educational']
#
# None
# ['Deliver', 'delivering', 'delivered', 'provide', 'carry', 'delivers', 'promised', 'bring', 'send', 'promise', 'produce', 'ResponsibilitiesActuarial', 'Business', 'industry', 'companies', 'businesses', 'marketing', 'company', 'corporate', 'financial', 'market', 'investment', 'management', 'Industrial', 'manufacturing', 'industries', 'sector', 'sectors', 'agricultural', 'construction', 'machinery', 'textile', 'industry', 'mining', 'Science', 'sciences', 'physics', 'institute', 'mathematics', 'studies', 'research', 'biology', 'university', 'psychology', 'economics', 'Finance', 'banking', 'foreign', 'minister', 'financial', 'commerce', 'investment', 'reform', 'government', 'fund', 'affairs', 'Management', 'financial', 'business', 'managers', 'investment', 'development', 'consulting', 'managing', 'marketing', 'corporate', 'asset', 'Systems', 'system', 'technologies', 'equipment', 'technology', 'software', 'computer', 'devices', 'components', 'communications', 'communication', 'Computer', 'computers', 'software', 'technology', 'pc', 'hardware', 'internet', 'desktop', 'electronic', 'systems', 'computing', 'Psychology', 'sociology', 'philosophy', 'anthropology', 'biology', 'psychiatry', 'neuroscience', 'science', 'professor', 'studies', 'economics', 'Information', 'data', 'knowledge', 'access', 'provided', 'intelligence', 'source', 'documents', 'web', 'internet', 'provide']
#
# None
# None
# ['Cape', 'coast', 'island', 'verde', 'isle', 'durban', 'islands', 'south', 'pacific', 'canary', 'ocean', 'Gqeberha', 'Durban', 'johannesburg', 'pretoria', 'bloemfontein', 'pietermaritzburg', 'galle', 'polokwane', 'newlands', 'cape', 'auckland', 'christchurch', 'TownQuantitative', 'Chain', 'chains', 'stores', 'store', 'supermarket', 'grocery', 'retail', 'retailer', 'restaurants', 'shop', 'supermarkets', 'Business', 'industry', 'companies', 'businesses', 'marketing', 'company', 'corporate', 'financial', 'market', 'investment', 'management', 'Management', 'financial', 'business', 'managers', 'investment', 'development', 'consulting', 'managing', 'marketing', 'corporate', 'asset', 'Trade', 'export', 'economic', 'trading', 'commerce', 'cooperation', 'exports', 'industry', 'wto', 'market', 'exchange', 'Shoprite', 'wegmans', 'dfs', 'safeway', 'fujisankei', 'funai', 'takefuji', 'lpga', 'crowne', 'mizuno', 'maurier', 'Leading', 'major', 'led', 'top', 'key', 'among', 'lead', 'third', 'as', 'second', 'both', 'The', 'this', 'part', 'one', 'of', 'same', 'first', 'on', 'its', 'as', 'that', 'Competencies', 'competences', 'competence', 'competency', 'self-discipline', 'strengths', 'methodologies', 'qualifications', 'teamwork', 'proficiencies', 'abilities', 'Supply', 'supplies', 'fuel', 'electricity', 'demand', 'shortage', 'oil', 'capacity', 'food', 'gasoline', 'equipment', 'Group', 'groups', 'based', 'members', 'organization', 'led', 'which', 'formed', 'alliance', 'joined', 'called', 'Skills', 'skill', 'abilities', 'talents', 'expertise', 'learning', 'ability', 'knowledge', 'experience', 'talent', 'techniques', 'Companies', 'firms', 'businesses', 'company', 'corporations', 'industry', 'business', 'manufacturers', 'makers', 'venture', 'industries', 'International', 'european', 'global', 'world', 'nations', 'regional', 'united', 'national', 'for', 'based', 'union']
#
# ['Theory', 'theories', 'concept', 'evolution', 'hypothesis', 'concepts', 'theoretical', 'notion', 'logic', 'philosophy', 'analysis', 'Accounting', 'auditing', 'audit', 'financial', 'auditors', 'practices', 'bookkeeping', 'management', 'corporate', 'disclosure', 'firms']
#
# ['Performance', 'performances', 'best', 'quality', 'success', 'well', 'performing', 'excellent', 'impressive', 'better', 'show', 'Danone', 'nestle', 'aventis', "l'oreal", 'wahaha', 'sanofi', 'inbev', 'pepsico', 'novartis', 'interbrew', 'groupe', 'Operations', 'operation', 'unit', 'operating', 'personnel', 'military', 'services', 'command', 'operational', 'units', 'force']

# %%
finalDf["ExtendedTag"]=finaltagls
# Out:
# C:\Users\Sachin\AppData\Local\Temp\ipykernel_16692\39582769.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   finalDf["ExtendedTag"]=finaltagls

# %%
finalDf.head()
# Out:
#     companyName             jobType    location  \
# 0         Hatch  Graduate programme     Gauteng
# 1  Tiger Brands  Graduate programme  Nationwide
# 2      Investec  Graduate programme     Gauteng
# 3       Nedbank  Graduate programme     Gauteng
# 4           BBD  Graduate programme     Gauteng
#
#                                             position  \
# 0       Chemical Engineering Graduate Programme 2023
# 1  Future Leaders Graduate Development Programme ...
# 2                       Tech Graduate Programme 2023
# 3  Quantitative Analyst Graduate Programme 2023 /...
# 4                            Graduate Programme 2023
#
#                                          description  \
# 0  Hatch is currently seeking the top performing ...
# 1  The Tiger Brands Future Leaders Development Pr...
# 2  Investec Sandton is looking for Tech Graduates...
# 3  ResponsibilitiesSeek opportunities to improve ...
# 4  BBD is an international software firm that sol...
#
#                                          Aggregation  \
# 0  Africa, SouthPrograms, Eng, Must, Metals, Prof...
# 1  Brands, Technology, Business, Food, Tiger, Fut...
# 2  Business, Systems, Informatics, Tech, Graduate...
# 3  Seek, ResponsibilitiesQuantitative, Applied, N...
# 4  Informatics, Diploma, Eng, Science, Continuous...
#
#                                          ExtendedTag
# 0  Africa, african, continent, asia, zimbabwe, so...
# 1  Brands, brand, products, cola, cosmetics, spec...
# 2  Business, industry, companies, businesses, mar...
# 3  Seek, seeking, sought, seeks, allow, agree, ac...
# 4  Informatics, biomedical, neuroscience, cyberne...

# %%
#The final has rows of orginal as well as the extended tags for the NER process

# %%
finalDf.to_csv("NER.csv")

# %%
#tests
nlp = spacy.load('en_core_web_md')
synth = "NER.csv"
extjobs = pd.read_csv(synth, index_col=0)

# %%
def get_top_sentence_indexes(prompt, querycols):
    prompt_words = nlp(prompt.lower())
    prompt_words = [token.text for token in prompt_words if not token.is_punct and not token.is_stop]

    all_sentences = []

    for column in querycols:
        for index, sentence in enumerate(extjobs[column]):
            if pd.notna(sentence):  # Check if sentence is not NaN
                tokens = nlp(str(sentence).lower())
                tokens = [token.text for token in tokens if not token.is_punct and not token.is_stop]
                doc = nlp(" ".join(tokens))

                similarities = [doc.similarity(nlp(word.lower())) for word in prompt_words]

                max_similarity = max(similarities)
                all_sentences.append((sentence, max_similarity, index))

    sorted_sentences = sorted(all_sentences, key=lambda x: x[1], reverse=True)
    top_10_indexes = [item[2] for item in sorted_sentences[:10]]

    return top_10_indexes

# %% [markdown]
# With extended tag only

# %%
# %%time
prompt = "chemical"
indexes = get_top_sentence_indexes(prompt, ["ExtendedTag"])
print("Indexes of top 10 sentences:", indexes)
# Out:
# Indexes of top 10 sentences: [7, 76, 145, 192, 53, 122, 27, 96, 165, 39]
# CPU times: total: 18 s
# Wall time: 18 s

# %%
extjobs.iloc[indexes]
# Out:
#                         companyName             jobType       location  \
# 7                         Accenture  Graduate programme        Gauteng
# 7                        Allan Gray          Internship      Cape Town
# 76  University of Johannesburg (UJ)          Internship        Gauteng
# 7                   Allen and Overy       Vacation work        Gauteng
# 53                       Rand Water  Graduate programme        Gauteng
# 53  National Heritage Council (NHC)          Internship        Gauteng
# 27                      AECI Mining  Graduate programme        Gauteng
# 27                           Wesgro          Internship      Cape Town
# 96        Department of Agriculture          Internship     Nationwide
# 39                     Umgeni Water  Graduate programme  KwaZulu-Natal
#
#                                position  \
# 7               Graduate Programme 2023
# 7         Internship Opportunities 2023
# 76        YES Internship Programme 2023
# 7             Winter Vacation Work 2023
# 53              Graduate Programme 2023
# 53         HR Internship Programme 2023
# 27  Engineering Graduate Programme 2023
# 27            Internship Programme 2023
# 96            Internship Programme 2023
# 39      Graduate Trainee Programme 2023
#
#                                           description  \
# 7   Accenture offers exceptional development and c...
# 7   Our Retail Operations team assist clients and ...
# 76  The Purpose of the Internship programme is to ...
# 7   Our one-week Summer Vacation Scheme will offer...
# 53  Rand Water invites suitably quallified and une...
# 53  The National Heritage Council of South Africa ...
# 27  Responsibilities:Assist with operational/execu...
# 27  Role Purpose: Promote, support and administer ...
# 96  The Department of Agriculture, Land Reform and...
# 39  Umgeni Water is offering a thirty six (36) mon...
#
#                                           Aggregation  \
# 7   StellenboschMust, Electrionic, Consulting, Gra...
# 7   StellenboschMust, Electrionic, Consulting, Gra...
# 76  StellenboschMust, Electrionic, Consulting, Gra...
# 7   StellenboschMust, Electrionic, Consulting, Gra...
# 53  Diploma, Chemistry, Analytical, Biology, Appli...
# 53  Diploma, Chemistry, Analytical, Biology, Appli...
# 27  Mechatronics, Requirements, Bachelor, Health, ...
# 27  Mechatronics, Requirements, Bachelor, Health, ...
# 96  Mechatronics, Requirements, Bachelor, Health, ...
# 39  Zulu, Kwa, Natal, South, AfricaUmgeni, Chemist...
#
#                                           ExtendedTag
# 7   StellenboschMust, Electrionic, Consulting, con...
# 7   StellenboschMust, Electrionic, Consulting, con...
# 76  StellenboschMust, Electrionic, Consulting, con...
# 7   StellenboschMust, Electrionic, Consulting, con...
# 53  Diploma, postgraduate, certificate, post-gradu...
# 53  Diploma, postgraduate, certificate, post-gradu...
# 27  Mechatronics, bio-technology, bio-medical, bio...
# 27  Mechatronics, bio-technology, bio-medical, bio...
# 96  Mechatronics, bio-technology, bio-medical, bio...
# 39  Zulu, xhosa, inkatha, buthelezi, maori, ifp, k...

# %%
# %%time
prompt = "I am looking for chemical engineering positions"
indexes = get_top_sentence_indexes(prompt, ["ExtendedTag"])
print("Indexes of top 10 sentences:", indexes)
# Out:
# Indexes of top 10 sentences: [15, 84, 153, 7, 76, 145, 192, 27, 96, 165]
# CPU times: total: 22.8 s
# Wall time: 22.9 s

# %%
extjobs.iloc[indexes]
# Out:
#                         companyName             jobType    location  \
# 15                            Sasol  Graduate programme  Mpumalanga
# 15                             ABSA          Internship     Gauteng
# 84  National Credit Regulator (NCR)          Internship     Gauteng
# 7                         Accenture  Graduate programme     Gauteng
# 7                        Allan Gray          Internship   Cape Town
# 76  University of Johannesburg (UJ)          Internship     Gauteng
# 7                   Allen and Overy       Vacation work     Gauteng
# 27                      AECI Mining  Graduate programme     Gauteng
# 27                           Wesgro          Internship   Cape Town
# 96        Department of Agriculture          Internship  Nationwide
#
#                                  position  \
# 15    Engineering Graduate Programme 2023
# 15     Graduate Internship Programme 2023
# 84  Procurement Internship Programme 2023
# 7                 Graduate Programme 2023
# 7           Internship Opportunities 2023
# 76          YES Internship Programme 2023
# 7               Winter Vacation Work 2023
# 27    Engineering Graduate Programme 2023
# 27              Internship Programme 2023
# 96              Internship Programme 2023
#
#                                           description  \
# 15  This role is for a position in the graduate de...
# 15  Position Title: Risk Management and Dispute Re...
# 84  Duration: 12 months contract\nStipend: R5391.0...
# 7   Accenture offers exceptional development and c...
# 7   Our Retail Operations team assist clients and ...
# 76  The Purpose of the Internship programme is to ...
# 7   Our one-week Summer Vacation Scheme will offer...
# 27  Responsibilities:Assist with operational/execu...
# 27  Role Purpose: Promote, support and administer ...
# 96  The Department of Agriculture, Land Reform and...
#
#                                           Aggregation  \
# 15  Technology, Eng, Industrial, Operations, Train...
# 15  Technology, Eng, Industrial, Operations, Train...
# 84  Technology, Eng, Industrial, Operations, Train...
# 7   StellenboschMust, Electrionic, Consulting, Gra...
# 7   StellenboschMust, Electrionic, Consulting, Gra...
# 76  StellenboschMust, Electrionic, Consulting, Gra...
# 7   StellenboschMust, Electrionic, Consulting, Gra...
# 27  Mechatronics, Requirements, Bachelor, Health, ...
# 27  Mechatronics, Requirements, Bachelor, Health, ...
# 96  Mechatronics, Requirements, Bachelor, Health, ...
#
#                                           ExtendedTag
# 15  Technology, technologies, computer, tech, soft...
# 15  Technology, technologies, computer, tech, soft...
# 84  Technology, technologies, computer, tech, soft...
# 7   StellenboschMust, Electrionic, Consulting, con...
# 7   StellenboschMust, Electrionic, Consulting, con...
# 76  StellenboschMust, Electrionic, Consulting, con...
# 7   StellenboschMust, Electrionic, Consulting, con...
# 27  Mechatronics, bio-technology, bio-medical, bio...
# 27  Mechatronics, bio-technology, bio-medical, bio...
# 96  Mechatronics, bio-technology, bio-medical, bio...

# %% [markdown]
# All columns

# %%
# %%time
prompt = "chemical"
indexes = get_top_sentence_indexes(prompt, extjobs.columns)
print("Indexes of top 10 sentences:", indexes)
# Out:
# C:\Users\Sachin\AppData\Local\Temp\ipykernel_16692\612133240.py:14: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   similarities = [doc.similarity(nlp(word.lower())) for word in prompt_words]
# Indexes of top 10 sentences: [7, 76, 145, 192, 53, 122, 7, 76, 145, 192]
# CPU times: total: 59.2 s
# Wall time: 59.6 s

# %%
extjobs.iloc[indexes]
# Out:
#                         companyName             jobType   location  \
# 7                         Accenture  Graduate programme    Gauteng
# 7                        Allan Gray          Internship  Cape Town
# 76  University of Johannesburg (UJ)          Internship    Gauteng
# 7                   Allen and Overy       Vacation work    Gauteng
# 53                       Rand Water  Graduate programme    Gauteng
# 53  National Heritage Council (NHC)          Internship    Gauteng
# 7                         Accenture  Graduate programme    Gauteng
# 7                        Allan Gray          Internship  Cape Town
# 76  University of Johannesburg (UJ)          Internship    Gauteng
# 7                   Allen and Overy       Vacation work    Gauteng
#
#                          position  \
# 7         Graduate Programme 2023
# 7   Internship Opportunities 2023
# 76  YES Internship Programme 2023
# 7       Winter Vacation Work 2023
# 53        Graduate Programme 2023
# 53   HR Internship Programme 2023
# 7         Graduate Programme 2023
# 7   Internship Opportunities 2023
# 76  YES Internship Programme 2023
# 7       Winter Vacation Work 2023
#
#                                           description  \
# 7   Accenture offers exceptional development and c...
# 7   Our Retail Operations team assist clients and ...
# 76  The Purpose of the Internship programme is to ...
# 7   Our one-week Summer Vacation Scheme will offer...
# 53  Rand Water invites suitably quallified and une...
# 53  The National Heritage Council of South Africa ...
# 7   Accenture offers exceptional development and c...
# 7   Our Retail Operations team assist clients and ...
# 76  The Purpose of the Internship programme is to ...
# 7   Our one-week Summer Vacation Scheme will offer...
#
#                                           Aggregation  \
# 7   StellenboschMust, Electrionic, Consulting, Gra...
# 7   StellenboschMust, Electrionic, Consulting, Gra...
# 76  StellenboschMust, Electrionic, Consulting, Gra...
# 7   StellenboschMust, Electrionic, Consulting, Gra...
# 53  Diploma, Chemistry, Analytical, Biology, Appli...
# 53  Diploma, Chemistry, Analytical, Biology, Appli...
# 7   StellenboschMust, Electrionic, Consulting, Gra...
# 7   StellenboschMust, Electrionic, Consulting, Gra...
# 76  StellenboschMust, Electrionic, Consulting, Gra...
# 7   StellenboschMust, Electrionic, Consulting, Gra...
#
#                                           ExtendedTag
# 7   StellenboschMust, Electrionic, Consulting, con...
# 7   StellenboschMust, Electrionic, Consulting, con...
# 76  StellenboschMust, Electrionic, Consulting, con...
# 7   StellenboschMust, Electrionic, Consulting, con...
# 53  Diploma, postgraduate, certificate, post-gradu...
# 53  Diploma, postgraduate, certificate, post-gradu...
# 7   StellenboschMust, Electrionic, Consulting, con...
# 7   StellenboschMust, Electrionic, Consulting, con...
# 76  StellenboschMust, Electrionic, Consulting, con...
# 7   StellenboschMust, Electrionic, Consulting, con...

# %%
# %%time
prompt = "I am looking for chemical engineering positions"
indexes = get_top_sentence_indexes(prompt, extjobs.columns)
print("Indexes of top 10 sentences:", indexes)
# Out:
# C:\Users\Sachin\AppData\Local\Temp\ipykernel_16692\612133240.py:14: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   similarities = [doc.similarity(nlp(word.lower())) for word in prompt_words]
# Indexes of top 10 sentences: [15, 84, 153, 7, 76, 145, 192, 15, 84, 153]
# CPU times: total: 1min 25s
# Wall time: 1min 26s

# %%
import spacy
import pandas as pd

nlp = spacy.load('en_core_web_md')

def get_top_sentence_indexes(prompt):
    synth = "NER.csv"

    extjobs = pd.read_csv(synth, index_col=0)

    prompt_words = [token.text.lower() for token in nlp(prompt.lower()) if not token.is_punct and not token.is_stop]
    extjobs_sentences = extjobs['ExtendedTag'].dropna()  # Use only the 'ExtendedTag' column and drop NaN values

    similarities = extjobs_sentences.apply(lambda sentence: nlp(sentence).similarity(nlp(' '.join(prompt_words))))

    sorted_sentences = similarities.sort_values(ascending=False)
    top_10_indexes = sorted_sentences.index[:10].tolist()

    return top_10_indexes

# %%
# %%time
prompt = "chemical"
indexes = get_top_sentence_indexes(prompt)
print("Indexes of top 10 sentences:", indexes)
# Out:
# Indexes of top 10 sentences: [7, 7, 7, 76, 27, 96, 27, 53, 53, 61]
# CPU times: total: 13 s
# Wall time: 13 s

# %%
# %%time
prompt = "I am looking for chemical engineering positions"
indexes = get_top_sentence_indexes(prompt)
print("Indexes of top 10 sentences:", indexes)
# Out:
# Indexes of top 10 sentences: [98, 29, 29, 30, 99, 30, 96, 27, 27, 78]
# CPU times: total: 12.3 s
# Wall time: 12.3 s

# %%
extjobs.iloc[indexes]
# Out:
#                      companyName             jobType       location  \
# 29               Mhlathuze Water          Internship  KwaZulu-Natal
# 29                         Eskom  Graduate programme        Gauteng
# 29                         Eskom  Graduate programme        Gauteng
# 30                 Standard Bank  Graduate programme        Gauteng
# 30                      Investec          Internship        Gauteng
# 30                 Standard Bank  Graduate programme        Gauteng
# 27                        Wesgro          Internship      Cape Town
# 27                   AECI Mining  Graduate programme        Gauteng
# 27                   AECI Mining  Graduate programme        Gauteng
# 9   South African National Parks          Internship   Eastern Cape
#
#                                            position  \
# 29                        Internship Programme 2023
# 29               IT Graduate Trainee Programme 2023
# 29               IT Graduate Trainee Programme 2023
# 30           CIB Technology Graduate Programme 2023
# 30          Tech Graduate Internship Programme 2023
# 30           CIB Technology Graduate Programme 2023
# 27                        Internship Programme 2023
# 27              Engineering Graduate Programme 2023
# 27              Engineering Graduate Programme 2023
# 9   Finance / Procurement Internship Programme 2023
#
#                                           description  \
# 29  Mhlathuze Water invites suitably qualified and...
# 29  Key ResponsibilitiesLiaise with customers thro...
# 29  Key ResponsibilitiesLiaise with customers thro...
# 30  Our graduate programme blends theoretical lear...
# 30  Investec Sandton is looking for Tech Graduates...
# 30  Our graduate programme blends theoretical lear...
# 27  Role Purpose: Promote, support and administer ...
# 27  Responsibilities:Assist with operational/execu...
# 27  Responsibilities:Assist with operational/execu...
# 9   Applications are hereby invited from graduates...
#
#                                           Aggregation  \
# 29  Technology, Business, Requirements, Building, ...
# 29  Technology, Business, Requirements, Building, ...
# 29  Technology, Business, Requirements, Building, ...
# 30  Informatics, Bank, Applied, Statistics, Techno...
# 30  Informatics, Bank, Applied, Statistics, Techno...
# 30  Informatics, Bank, Applied, Statistics, Techno...
# 27  Mechatronics, Requirements, Bachelor, Health, ...
# 27  Mechatronics, Requirements, Bachelor, Health, ...
# 27  Mechatronics, Requirements, Bachelor, Health, ...
# 9   Deliver, ResponsibilitiesActuarial, Business, ...
#
#                                           ExtendedTag
# 29  Technology, technologies, computer, tech, soft...
# 29  Technology, technologies, computer, tech, soft...
# 29  Technology, technologies, computer, tech, soft...
# 30  Informatics, biomedical, neuroscience, cyberne...
# 30  Informatics, biomedical, neuroscience, cyberne...
# 30  Informatics, biomedical, neuroscience, cyberne...
# 27  Mechatronics, bio-technology, bio-medical, bio...
# 27  Mechatronics, bio-technology, bio-medical, bio...
# 27  Mechatronics, bio-technology, bio-medical, bio...
# 9   Deliver, delivering, delivered, provide, carry...

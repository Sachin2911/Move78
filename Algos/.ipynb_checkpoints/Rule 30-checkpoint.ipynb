# %%
#Libraries
import numpy as np
import pandas as pd
import spacy

nlp = spacy.load('en_core_web_md')

# %%
# Importing data into dataframes
gradProgramsJson = "../Data/Gradeo-data/graduateProgrammes.json"
internshipsJson = "../Data/Gradeo-data/internships.json"
vacworkJson = "../Data/Gradeo-data/vacwork.json"

gradProgramsDf = pd.read_json(gradProgramsJson)
internshipsDf = pd.read_json(internshipsJson)
vacworkDf = pd.read_json(vacworkJson)

# %%
# Dropping all the unnesecary columns => companyLogo; applicationURL; deadline
def coldropper(df):
    df.drop(["companyLogo", "applicationURL", "deadline"], axis=1, inplace=True)

# %%
coldropper(gradProgramsDf)
coldropper(internshipsDf)
coldropper(vacworkDf)

# %%
gradProgramsDf.head(2)
# Out:
#     companyName             jobType      location  \
# 0         Hatch  Graduate programme  Johannesburg
# 1  Tiger Brands  Graduate programme   Nation wide
#
#                                             position  \
# 0       Chemical Engineering Graduate Programme 2023
# 1  Future Leaders Graduate Development Programme ...
#
#                                          description
# 0  Hatch is currently seeking the top performing ...
# 1  The Tiger Brands Future Leaders Development Pr...

# %%
internshipsDf.head(2)
# Out:
#                      companyName     jobType      location  \
# 0  Gauteng Provincial Government  Internship  Johannesburg
# 1           Joburg City Theatres  Internship  Johannesburg
#
#                                             position  \
# 0     Youth Training / Internship Opportunities 2023
# 1  Purchasing / Supply Chain Internship Programme...
#
#                                          description
# 0  SKills and Training for Solar Technicians 2023...
# 1  Joburg City Theatres is contributing towards s...

# %%
vacworkDf.head(2)
# Out:
#   companyName        jobType        location  \
# 0         BDO  Vacation work  Port Elizabeth
# 1       Moore  Vacation work    Johannesburg
#
#                                             position  \
# 0  Readiness Experience Drive (RED) Vacation Work...
# 1     Winter Vacation Work Experience Programme 2023
#
#                                          description
# 0  Our RED Programme is the ideal vacation work o...
# 1  The Moore Johannesburg Vacation Program is ope...

# %%
gradProgramsDf["description"][0]
# Out:
# 'Hatch is currently seeking the top performing and highly motivated\xa0Chemical Engineering\xa0final year students to join us on our 2024 Graduate Selection Journey.\n\xa0\nAs the successful candidate, you will:Be encouraged to be the best version of yourself with many opportunities to pursue work in Mining & Metals, Energy, Digital, or Infrastructure sectors.\nHave the benefit of formal and informal mentorship from some of the leading minds and authorities in the industry.\nHave the opportunity to gain project experience in South Africa and around the world.\nCollaborate with different people across a multitude of cultures around our global organization.\nWork in an exciting environment where you can use your Engineering degree\xa0in your choice of traditional sectors or emerging, innovative, and evolving industries.\nBe part of our local Professional\xa0Development Programs.\nMinimum Requirements:You must be a South African Citizen.\nCompleted or Final year\xa0\xa0BSc or BEng in Chemical Engineering\xa0at a recognized Tertiary Institution\nMust have 0 or less than\xa012 months working experience.\xa0\nYou must have maintained an average academic achievement of 70% or above.\nBe flexible to work in any province within South Africa.'

# %%
locationlist = list(gradProgramsDf["location"].unique()) + list(internshipsDf["location"].unique())+ list(vacworkDf["location"].unique())

# %%
locationlist = set(locationlist)

# %%
locationlist
# Out:
# {'Addo Elephant National Park',
#  'Alberton',
#  'Boksburg',
#  'Bronkhorstspruit',
#  'Cape Town',
#  'Centurion',
#  'Durban',
#  'Gauteng',
#  'Germiston',
#  'Hotazel',
#  'Johannesburg',
#  'Kempton Park',
#  'Kuruman',
#  'KwaZulu-Natal',
#  'Midrand',
#  'Modderfontein',
#  'Mpumalanga',
#  'Mulbarton',
#  'Nation wide',
#  'North West',
#  'Polokwane',
#  'Port Elizabeth',
#  'Pretoria',
#  'Richards Bay',
#  'Roodepoort',
#  'Rustenburg',
#  'Sandton',
#  'Thohoyandou',
#  'Vereeniging',
#  'Weltevredenpark'}

# %%
location_mapping_dict = {
    'Addo Elephant National Park':'Eastern Cape',
 'Alberton':"Gauteng",
 'Boksburg':"Gauteng",
 'Bronkhorstspruit':"Gauteng",
 'Cape Town':"Cape Town",
 'Centurion':"Gauteng",
 'Durban':"KwaZulu-Natal",
 'Gauteng':"Gauteng",
 'Germiston':"Gauteng",
 'Hotazel':"Northern Cape",
 'Johannesburg':"Gauteng",
 'Kempton Park':"Gauteng",
 'Kuruman':"Northern Cape",
 'KwaZulu-Natal':"KwaZulu-Natal",
 'Midrand':"Gauteng",
 'Modderfontein':"Gauteng",
 'Mpumalanga':"Mpumalanga",
 'Mulbarton':"Gauteng",
 'Nation wide':"Nationwide",
 'North West':"North West",
 'Polokwane':"Limpopo",
 'Port Elizabeth':"Eastern Cape",
 'Pretoria':"Gauteng",
 'Richards Bay':"KwaZulu-Natal",
 'Roodepoort':"Gauteng",
 'Rustenburg':"North West",
 'Sandton':"Gauteng",
 'Thohoyandou':"Limpopo",
 'Vereeniging':"Gauteng",
 'Weltevredenpark':"Gauteng",
}

# %%
def location_mapper(dflist, location_mapping_dict):
    for i in dflist:
        i["location"] = i["location"].map(location_mapping_dict)

# %%
location_mapper([gradProgramsDf, internshipsDf, vacworkDf], location_mapping_dict)

# %%
locationlist_refined = list(gradProgramsDf["location"].unique()) + list(internshipsDf["location"].unique())+ list(vacworkDf["location"].unique())

# %%
set(locationlist_refined)
# Out:
# {'Cape Town',
#  'Eastern Cape',
#  'Gauteng',
#  'KwaZulu-Natal',
#  'Limpopo',
#  'Mpumalanga',
#  'Nationwide',
#  'North West',
#  'Northern Cape'}

# %%
#Unified DataFrame
jobsDf = pd.concat([gradProgramsDf, internshipsDf, vacworkDf], axis=0)

# %%
jobsDf.shape
# Out:
# (198, 5)

# %%
gradProgramsDf["description"][0]
# Out:
# 'Hatch is currently seeking the top performing and highly motivated\xa0Chemical Engineering\xa0final year students to join us on our 2024 Graduate Selection Journey.\n\xa0\nAs the successful candidate, you will:Be encouraged to be the best version of yourself with many opportunities to pursue work in Mining & Metals, Energy, Digital, or Infrastructure sectors.\nHave the benefit of formal and informal mentorship from some of the leading minds and authorities in the industry.\nHave the opportunity to gain project experience in South Africa and around the world.\nCollaborate with different people across a multitude of cultures around our global organization.\nWork in an exciting environment where you can use your Engineering degree\xa0in your choice of traditional sectors or emerging, innovative, and evolving industries.\nBe part of our local Professional\xa0Development Programs.\nMinimum Requirements:You must be a South African Citizen.\nCompleted or Final year\xa0\xa0BSc or BEng in Chemical Engineering\xa0at a recognized Tertiary Institution\nMust have 0 or less than\xa012 months working experience.\xa0\nYou must have maintained an average academic achievement of 70% or above.\nBe flexible to work in any province within South Africa.'

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
doc = nlp(gradProgramsDf["description"][1])

for ent in doc.ents:
    print(ent.text, "|", ent.label_)
# Out:
# The Tiger Brands  | ORG
# 24-month | DATE
# South African | NORP
# Graduate Internship Opportunities | ORG
# Customer Graduate | PERSON
# Food Technology | ORG
# Chemical Engineering | ORG
# GraduateBSc/BEng Degree ( | ORG
# Information Technology | ORG
# Information Technology OR Computer Science
# Mechanical Engineering | ORG
# GraduateBSc/BEng Degree (Mechanical | ORG
# Economics | ORG
# Strategic Communication | ORG
# GraduateBSc/BEng Degree | ORG
# Supply Chain | WORK_OF_ART
# Supply Chain | WORK_OF_ART
# Accounting & | ORG
# 2 | CARDINAL

# %%
nlp.pipe_labels['ner']
# Out:
# ['CARDINAL',
#  'DATE',
#  'EVENT',
#  'FAC',
#  'GPE',
#  'LANGUAGE',
#  'LAW',
#  'LOC',
#  'MONEY',
#  'NORP',
#  'ORDINAL',
#  'ORG',
#  'PERCENT',
#  'PERSON',
#  'PRODUCT',
#  'QUANTITY',
#  'TIME',
#  'WORK_OF_ART']

# %%
jobsDf
# Out:
#         companyName             jobType       location  \
# 0             Hatch  Graduate programme        Gauteng
# 1      Tiger Brands  Graduate programme     Nationwide
# 2          Investec  Graduate programme        Gauteng
# 3           Nedbank  Graduate programme        Gauteng
# 4               BBD  Graduate programme        Gauteng
# ..              ...                 ...            ...
# 8          Mr Price       Vacation work  KwaZulu-Natal
# 9              Visa       Vacation work        Gauteng
# 10             Citi       Vacation work        Gauteng
# 11       Allan Gray       Vacation work      Cape Town
# 12  Bank of America       Vacation work        Gauteng
#
#                                              position  \
# 0        Chemical Engineering Graduate Programme 2023
# 1   Future Leaders Graduate Development Programme ...
# 2                        Tech Graduate Programme 2023
# 3   Quantitative Analyst Graduate Programme 2023 /...
# 4                             Graduate Programme 2023
# ..                                                ...
# 8   Winter Vacation Workplace Experience Programme...
# 9   June Vacation Internship - Data Science (For C...
# 10  EMEA Banking Winter Vacation Internship Progra...
# 11            Internship for final year students 2023
# 12          Investment Banking Winter Internship 2023
#
#                                           description
# 0   Hatch is currently seeking the top performing ...
# 1   The Tiger Brands Future Leaders Development Pr...
# 2   Investec Sandton is looking for Tech Graduates...
# 3   ResponsibilitiesSeek opportunities to improve ...
# 4   BBD is an international software firm that sol...
# ..                                                ...
# 8   Workplace Experience Programme (WEP) is our an...
# 9   ResponsibilitiesBe an out-of-the-box thinker w...
# 10  Whether you’ve got prior financial industry ex...
# 11  Purpose of the role: Our Client Service Centre...
# 12  Our Winter Analyst programme is designed to of...
#
# [198 rows x 5 columns]

# %%
#Using Named Entity recognition to extract features
ner = nlp.pipe_labels['ner']
for i in ner:
    jobsDf[i] = ''

# %%
#NER main
for ind,i in enumerate(jobsDf["description"]):
    try:
        doc = nlp(i)
        for ent in doc.ents:
            jobsDf[ent.label_][ind] = jobsDf[ent.label_][ind] + "," + ent.text
    except:
        print("Error")
# Out:
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error
# Error

# %%
jobsDf.tail()
# Out:
#         companyName        jobType       location  \
# 8          Mr Price  Vacation work  KwaZulu-Natal
# 9              Visa  Vacation work        Gauteng
# 10             Citi  Vacation work        Gauteng
# 11       Allan Gray  Vacation work      Cape Town
# 12  Bank of America  Vacation work        Gauteng
#
#                                              position  \
# 8   Winter Vacation Workplace Experience Programme...
# 9   June Vacation Internship - Data Science (For C...
# 10  EMEA Banking Winter Vacation Internship Progra...
# 11            Internship for final year students 2023
# 12          Investment Banking Winter Internship 2023
#
#                                           description CARDINAL          DATE  \
# 8   Workplace Experience Programme (WEP) is our an...            ,a 12 month
# 9   ResponsibilitiesBe an out-of-the-box thinker w...
# 10  Whether you’ve got prior financial industry ex...
# 11  Purpose of the role: Our Client Service Centre...      ,12  ,1 June 2023
# 12  Our Winter Analyst programme is designed to of...
#
#                                         EVENT FAC              GPE  ... MONEY  \
# 8                                                  ,South Africa’s  ...
# 9   ,Recent Graduates / Final year University                       ...
# 10                                                       ,Gqeberha  ...
# 11                                                          ,CA(SA  ...
# 12                                                                  ...
#
#               NORP ORDINAL                                                ORG  \
# 8                           ,Wholesale & Retail SETA,the JD Group - one,Ex...
# 9   ,South African          ,ResponsibilitiesDeliver,Participation,Commerc...
# 10                          ,The Shoprite Group of Companies Supply Chain,...
# 11                                      ,CA,the Theory of Accounting,CTA,PGDA
# 12                                                       ,Danone's Operations
#
#    PERCENT PERSON PRODUCT QUANTITY TIME                     WORK_OF_ART
# 8
# 9                  ,Maths                ,Participate,Actuarial Science
# 10
# 11    ,60%
# 12
#
# [5 rows x 23 columns]

# %%
import gensim.downloader as api
from gensim.models import KeyedVectors
from typing import Type
# Load pre-trained word-vectors from gensim-data
word_vectors = api.load("glove-wiki-gigaword-100")

# %%
def print_synonyms(word_vectors: Type[KeyedVectors], seed_word: str, n_synonyms):
    result = word_vectors.most_similar(positive=[seed_word])
    print(f"The synonyms for '{seed_word}':")
    for r in result[:n_synonyms]:
        print(r[0], r[1])

# %%
print_synonyms(word_vectors, seed_word="consulting", n_synonyms=10)
# Out:
# The synonyms for 'consulting':
# consultant 0.7932726144790649
# consultancy 0.7872053980827332
# firm 0.7739571332931519
# consultants 0.7732748985290527
# management 0.7026959657669067
# associates 0.6969802379608154
# business 0.6804054975509644
# mckinsey 0.6548133492469788
# marketing 0.6362238526344299
# company 0.6341273188591003

# %%
def calculate_missing_percentage(df):
    total_rows = len(df)
    missing_percentages = (df.isnull().sum() / total_rows) * 100
    return missing_percentages

# %%
jobsDf.columns
# Out:
# Index(['companyName', 'jobType', 'location', 'position', 'description',
#        'CARDINAL', 'DATE', 'EVENT', 'FAC', 'GPE', 'LANGUAGE', 'LAW', 'LOC',
#        'MONEY', 'NORP', 'ORDINAL', 'ORG', 'PERCENT', 'PERSON', 'PRODUCT',
#        'QUANTITY', 'TIME', 'WORK_OF_ART'],
#       dtype='object')

# %%
pd.set_option('display.max_columns', None)
jobsDf.head()
# Out:
#     companyName             jobType    location  \
# 0         Hatch  Graduate programme     Gauteng
# 1  Tiger Brands  Graduate programme  Nationwide
# 2      Investec  Graduate programme     Gauteng
# 3       Nedbank  Graduate programme     Gauteng
# 4           BBD  Graduate programme     Gauteng
#
#                                             position  \
# 0       Chemical Engineering Graduate Programme 2023
# 1  Future Leaders Graduate Development Programme ...
# 2                       Tech Graduate Programme 2023
# 3  Quantitative Analyst Graduate Programme 2023 /...
# 4                            Graduate Programme 2023
#
#                                          description  CARDINAL  \
# 0  Hatch is currently seeking the top performing ...        ,0
# 1  The Tiger Brands Future Leaders Development Pr...        ,2
# 2  Investec Sandton is looking for Tech Graduates...  ,one,one
# 3  ResponsibilitiesSeek opportunities to improve ...
# 4  BBD is an international software firm that sol...
#
#                                        DATE                        EVENT FAC  \
# 0            ,year,2024,less than 12 months  ,Graduate Selection Journey
# 1                                 ,24-month
# 2
# 3
# 4  ,the very first week,their first 8 weeks
#
#                           GPE LANGUAGE LAW LOC MONEY  \
# 0  ,South Africa,South Africa
# 1
# 2
# 3
# 4
#
#                                NORP ORDINAL  \
# 0                    ,South African
# 1                    ,South African
# 2  ,Investec,South African,Investec
# 3
# 4      ,South African,South African  ,first
#
#                                                  ORG PERCENT  \
# 0  ,Chemical Engineering,Mining & Metals, Energy,...    ,70%
# 1  ,The Tiger Brands ,Graduate Internship Opportu...
# 2  ,the Investec Tech 2024,Grad Programme,the Inv...
# 3  ,Nedbank,Contribute,the Nedbank Quants Trainin...
# 4  ,BBD,BBD,Continuous Learning Programme,The BBD...
#
#                               PERSON PRODUCT QUANTITY TIME  \
# 0
# 1                 ,Customer Graduate
# 2          ,Required Fields of Study
# 3  ,Required Fields,Pure Mathematics
# 4
#
#                   WORK_OF_ART
# 0
# 1  ,Supply Chain,Supply Chain
# 2
# 3
# 4

# %%
jobsDf.drop(["CARDINAL", "DATE", "LANGUAGE", "LAW", "LOC", "MONEY", "NORP", "ORDINAL", "PERCENT", "QUANTITY", "TIME"], axis=1, inplace=True)

# %%
jobsDf["WORK_OF_ART"].unique()
# Out:
# array(['', ',Supply Chain,Supply Chain',
#        ',Supply Chain\nLogistics\nEconomics\nManagement\nHuman Resources\xa0Trainee Programme,Science Honours,Electrical Engineering\xa0Trainee ProgrammeB.Engineering/ B.Sc.',
#        ',Participate,Actuarial Science', ',Quantitative Analysis',
#        ',Bsc Environmental Science\nRelevant Degree,Electrical or Electronic',
#        ',Requirements',
#        ',Process Improvement\nRoot Cause Analysis\nSimulations\nExpense Analysis\nAccounts Receivable\nForex\nNet working Capital Reporting\nRequirements:Grade 12 / Matric\nDegree,Reliable',
#        ',Electrical Engineering\nMechanical Engineering\nMechatronics\nApplicant Requirements',
#        ',Actuarial Science\nBEng Electrical and Electronic Enineering\nBEng Industrial Engineering\nIndustrial Psychology\n',
#        ',Electrical Engineering\nMechanical Engineering: BEng,Civil Engineering\nGeographic Information Systems',
#        ',B.Com Honours Degree in either;Logistics\nSupply Chain\xa0\n',
#        ',Electrical Engineering\nFinancial,Supply Chain',
#        ',Insights and Analytics', ',Requirements:Matric / Grade 12\xa0\n',
#        ',Fields of Study:\nA university degree',
#        ',Actuarial Science or Investment',
#        ',Program Structure:Intensive learning and development program',
#        ',Good Presentation Skills', ',Internal Audit Intern\nRef No:\xa0',
#        ',Master’s Degree in Industrial Psychology (HPCSA Registered student Industrial Psychologist',
#        ",AdminApply Online for this Internship ProgrammeDepartment,Human ResourcesApply Online for this Internship ProgrammeDepartment:\xa0School of EducationHonour's,Human ResourcesApply Online for this Internship ProgrammeDepartment,ChemistryApply Online",
#        ',2023)Data Science\nApplied Mathematics\nStatistics\nEngineering (Electrical, Chemical, Mechanical',
#        ',Electrical Engineering\nPurchasing Young Professional\nNational Diploma /\xa0',
#        ',a Master’s', ',Post Grad', ',Computer Science\xa0\n',
#        ',Electrical Engineering',
#        ',Young Talent Programs,the Testing of Switchgear',
#        ',Light Current Engineering\nEngineer in Training:\xa0Mechanical EngineeringDegree',
#        ',Master’s Studentship: Internet of Things\xa0\nAn Honours,A Master’s degree,Doctoral Studentship: Cybersecurity\nA Master’s degree',
#        ',Electrical\xa0Engineering,Library and Information Science or Archival Studies\nEnvironmental Management',
#        ',Salary / Remuneration',
#        ',Library Information Science\nArchival Science\nMultimedia Studies,Electrical and Computer Engineering,Tiger Brands: Corporate Affairs Graduate Programme\nCompany,Supply Chain\nLogistics\nEconomics\nManagement\nRand Water: Human Resources,Actuarial Science,Science Honours',
#        ',Work Independently\nAbility', ',Actuarial Science',
#        ',Forensic Investigation\nPrudential Supervision',
#        ',Collaboration – Cloud Solutions',
#        ',Purchase Requisition,Requirements',
#        ',Supply Chain\xa0Interns\nNational Diploma/Degree,Forensic and Investigation\xa0Interns\nNational Diploma/Degree'],
#       dtype=object)

# %%
jobsDf.head()
# Out:
#     companyName             jobType    location  \
# 0         Hatch  Graduate programme     Gauteng
# 1  Tiger Brands  Graduate programme  Nationwide
# 2      Investec  Graduate programme     Gauteng
# 3       Nedbank  Graduate programme     Gauteng
# 4           BBD  Graduate programme     Gauteng
#
#                                             position  \
# 0       Chemical Engineering Graduate Programme 2023
# 1  Future Leaders Graduate Development Programme ...
# 2                       Tech Graduate Programme 2023
# 3  Quantitative Analyst Graduate Programme 2023 /...
# 4                            Graduate Programme 2023
#
#                                          description  \
# 0  Hatch is currently seeking the top performing ...
# 1  The Tiger Brands Future Leaders Development Pr...
# 2  Investec Sandton is looking for Tech Graduates...
# 3  ResponsibilitiesSeek opportunities to improve ...
# 4  BBD is an international software firm that sol...
#
#                          EVENT FAC                         GPE  \
# 0  ,Graduate Selection Journey      ,South Africa,South Africa
# 1
# 2
# 3
# 4
#
#                                                  ORG  \
# 0  ,Chemical Engineering,Mining & Metals, Energy,...
# 1  ,The Tiger Brands ,Graduate Internship Opportu...
# 2  ,the Investec Tech 2024,Grad Programme,the Inv...
# 3  ,Nedbank,Contribute,the Nedbank Quants Trainin...
# 4  ,BBD,BBD,Continuous Learning Programme,The BBD...
#
#                               PERSON PRODUCT                 WORK_OF_ART
# 0
# 1                 ,Customer Graduate          ,Supply Chain,Supply Chain
# 2          ,Required Fields of Study
# 3  ,Required Fields,Pure Mathematics
# 4

# %%
collist = ["FAC", "GPE", "ORG", "PERSON", "PRODUCT", "WORK_OF_ART"]
df = pd.DataFrame( columns=collist)

# %%
joblist = []

# %%
import re
for i in collist:
    for ind, j in enumerate(jobsDf[i]):
        refined = set(str(j).replace("0", "").replace("...\n","").split(","))
        reflist = list(refined)
        filteredls = [element for element in reflist if len(element) >= 3]
        finalstr = ', '.join(filteredls)
        finalstr = re.sub(r'\s+|[()\xa0&]', ' ', finalstr)
        word_list = re.findall(r'[A-Z][a-z]*', finalstr)
        filteredls = [element for element in word_list if len(element) >= 3]
        filteredls = list(set(filteredls))
        finalstr = ', '.join(filteredls)
        joblist.append(finalstr)
    df[i] = joblist
    joblist = []

# %%
df["Agg"] = df["FAC"] + df["GPE"] + df["ORG"] + df["PERSON"] + df["PRODUCT"] + df["WORK_OF_ART"]

# %%
df["Agg"][1]
# Out:
# 'The, Opportunities, Tiger, Degree, Technology, Communication, Information, Graduate, Computer, Brands, Food, Chemical, Mechanical, Strategic, Economics, Internship, Eng, Science, Engineering, AccountingGraduate, CustomerSupply, Chain'

# %%
df["Agg"]
# Out:
# 0      South, AfricaChemical, Institution, Digital, E...
# 1      The, Opportunities, Tiger, Degree, Technology,...
# 2      Commerce, Informatics, Investec, Grad, Busines...
# 3      Improve, Nedbank, Financial, Quantitative, Con...
# 4      The, Continuous, Informatics, Grad, Programme,...
#                              ...
# 193    South, AfricaWholesale, Institution, Group, In...
# 194    Commerce, Industrial, Responsibilities, Busine...
# 195    GqeberhaInternational, Skills, Durban, Group, ...
# 196                                   Theory, Accounting
# 197                                   Danone, Operations
# Name: Agg, Length: 198, dtype: object

# %%
extjobs = jobsDf[["companyName", "jobType", "location", "position", "description"]]

# %%
extjobs["Aggregation"] = df["Agg"]
# Out:
# C:\Users\Sachin\AppData\Local\Temp\ipykernel_16144\3597787162.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   extjobs["Aggregation"] = df["Agg"]

# %%
extjobs
# Out:
#         companyName             jobType       location  \
# 0             Hatch  Graduate programme        Gauteng
# 1      Tiger Brands  Graduate programme     Nationwide
# 2          Investec  Graduate programme        Gauteng
# 3           Nedbank  Graduate programme        Gauteng
# 4               BBD  Graduate programme        Gauteng
# ..              ...                 ...            ...
# 8          Mr Price       Vacation work  KwaZulu-Natal
# 9              Visa       Vacation work        Gauteng
# 10             Citi       Vacation work        Gauteng
# 11       Allan Gray       Vacation work      Cape Town
# 12  Bank of America       Vacation work        Gauteng
#
#                                              position  \
# 0        Chemical Engineering Graduate Programme 2023
# 1   Future Leaders Graduate Development Programme ...
# 2                        Tech Graduate Programme 2023
# 3   Quantitative Analyst Graduate Programme 2023 /...
# 4                             Graduate Programme 2023
# ..                                                ...
# 8   Winter Vacation Workplace Experience Programme...
# 9   June Vacation Internship - Data Science (For C...
# 10  EMEA Banking Winter Vacation Internship Progra...
# 11            Internship for final year students 2023
# 12          Investment Banking Winter Internship 2023
#
#                                           description  \
# 0   Hatch is currently seeking the top performing ...
# 1   The Tiger Brands Future Leaders Development Pr...
# 2   Investec Sandton is looking for Tech Graduates...
# 3   ResponsibilitiesSeek opportunities to improve ...
# 4   BBD is an international software firm that sol...
# ..                                                ...
# 8   Workplace Experience Programme (WEP) is our an...
# 9   ResponsibilitiesBe an out-of-the-box thinker w...
# 10  Whether you’ve got prior financial industry ex...
# 11  Purpose of the role: Our Client Service Centre...
# 12  Our Winter Analyst programme is designed to of...
#
#                                           Aggregation
# 0   South, AfricaChemical, Institution, Digital, E...
# 1   The, Opportunities, Tiger, Degree, Technology,...
# 2   Commerce, Informatics, Investec, Grad, Busines...
# 3   Improve, Nedbank, Financial, Quantitative, Con...
# 4   The, Continuous, Informatics, Grad, Programme,...
# ..                                                ...
# 8   South, AfricaWholesale, Institution, Group, In...
# 9   Commerce, Industrial, Responsibilities, Busine...
# 10  GqeberhaInternational, Skills, Durban, Group, ...
# 11                                 Theory, Accounting
# 12                                 Danone, Operations
#
# [198 rows x 6 columns]

# %%
import gensim.downloader as api
from gensim.models import KeyedVectors
from typing import Type
# Load pre-trained word-vectors from gensim-data
word_vectors = api.load("glove-wiki-gigaword-100") 

def print_synonyms(word_vectors: Type[KeyedVectors], seed_word: str, n_synonyms):
    result = word_vectors.most_similar(positive=[seed_word])
    print(f"The synonyms for '{seed_word}':")
    for r in result[:n_synonyms]:
        print(r[0], r[1])
# Out:
# The synonyms for 'consulting':
# consultant 0.7932726144790649
# consultancy 0.7872053980827332
# firm 0.7739571332931519
# consultants 0.7732748985290527
# management 0.7026959657669067
# associates 0.6969802379608154
# business 0.6804054975509644
# mckinsey 0.6548133492469788
# marketing 0.6362238526344299
# company 0.6341273188591003

# %%
def synoget(word_vectors: Type[KeyedVectors], seed_word: str):
    synlis = []
    try:
        result = word_vectors.most_similar(positive=[seed_word.lower()])
        for r in result:
            synlis.append(r[0])
    except:
        print("None")
    return synlis

# %%
synoget(word_vectors, seed_word="Institution")
# Out:
# ['institutions',
#  'society',
#  'institute',
#  'established',
#  'private',
#  'university',
#  'foundation',
#  'academic',
#  'education',
#  'educational']

# %%
##Extended tag generation
finaltagls = []
for ind, i in enumerate(extjobs["Aggregation"]):
    synonym_ls = []
    i = i.replace(" ", "")
    list_tags = i.split(",")
    for i in list_tags:
        synonym_ls.append(i)
        synonym_ls = synonym_ls + synoget(word_vectors, seed_word=i)
    synowords = ', '.join(synonym_ls)
    finaltagls.append(synowords)
    print(synonym_ls)
    print(" ")
# Out:
# None
# ['South', 'north', 'west', 'east', 'western', 'southern', 'southeast', 'africa', 'korea', 'northern', 'northeast', 'AfricaChemical', 'Institution', 'institutions', 'society', 'institute', 'established', 'private', 'university', 'foundation', 'academic', 'education', 'educational', 'Digital', 'electronic', 'analog', 'video', 'audio', 'multimedia', 'computer', 'wireless', 'interactive', 'internet', 'computers', 'Energy', 'resources', 'gas', 'renewable', 'natural', 'petroleum', 'electricity', 'oil', 'power', 'development', 'fuel', 'Metals', 'minerals', 'copper', 'commodities', 'ferrous', 'commodity', 'ores', 'aluminium', 'alloys', 'chemicals', 'zinc', 'Mining', 'coal', 'mines', 'copper', 'industrial', 'ore', 'mine', 'mineral', 'exploration', 'minerals', 'logging', 'Eng', 'fra', 'aus', 'capt', 'saracens', 'leicester', 'rsa', 'esp', 'harlequins', '/', 'gareth', 'Engineering', 'sciences', 'technology', 'technical', 'science', 'mechanical', 'engineers', 'institute', 'mathematics', 'biomedical', 'physics', 'Tertiary', 'secondary', 'schooling', 'post-secondary', 'vocational', 'quaternary', 'colleges', 'undergraduate', 'pupils', 'education', 'university-level']
#
# None
# None
# ['The', 'this', 'part', 'one', 'of', 'same', 'first', 'on', 'its', 'as', 'that', 'Opportunities', 'opportunity', 'possibilities', 'advantages', 'advantage', 'benefit', 'experience', 'innovation', 'resources', 'development', 'encourage', 'Tiger', 'tigers', 'leopard', 'elephant', 'woods', 'crocodile', 'dragon', 'lion', 'turtle', 'rebel', 'elephants', 'Degree', 'bachelor', 'doctorate', 'graduate', 'degrees', 'undergraduate', 'graduated', 'ph.d.', 'graduating', 'phd', 'b.a.', 'Technology', 'technologies', 'computer', 'tech', 'software', 'systems', 'innovation', 'technological', 'engineering', 'research', 'computing', 'Communication', 'communications', 'systems', 'services', 'technology', 'knowledge', 'information', 'learning', 'interaction', 'navigation', 'connections', 'Information', 'data', 'knowledge', 'access', 'provided', 'intelligence', 'source', 'documents', 'web', 'internet', 'provide', 'Graduate', 'undergraduate', 'graduating', 'harvard', 'enrolled', 'graduated', 'college', 'graduates', 'faculty', 'university', 'yale', 'Computer', 'computers', 'software', 'technology', 'pc', 'hardware', 'internet', 'desktop', 'electronic', 'systems', 'computing', 'Brands', 'brand', 'products', 'cola', 'cosmetics', 'specialty', 'stores', 'foods', 'drinks', 'marketed', 'beverages', 'Food', 'foods', 'supplies', 'products', 'meat', 'supply', 'feed', 'medicines', 'meals', 'coffee', 'goods', 'Chemical', 'chemicals', 'biological', 'toxic', 'materials', 'biochemical', 'compounds', 'industrial', 'components', 'nuclear', 'pesticides', 'Mechanical', 'electrical', 'engineering', 'hydraulic', 'mechanics', 'technical', 'hydraulics', 'physics', 'structural', 'components', 'design', 'Strategic', 'operational', 'tactical', 'strategy', 'objectives', 'cooperation', 'joint', 'objective', 'aim', 'security', 'policy', 'Economics', 'sociology', 'professor', 'science', 'philosophy', 'psychology', 'mathematics', 'sciences', 'physics', 'harvard', 'institute', 'Internship', 'apprenticeship', 'internships', 'sabbatical', 'residencies', 'post-graduate', 'semester', 'undergraduate', 'vocational', 'secretarial', 'part-time', 'Eng', 'fra', 'aus', 'capt', 'saracens', 'leicester', 'rsa', 'esp', 'harlequins', '/', 'gareth', 'Science', 'sciences', 'physics', 'institute', 'mathematics', 'studies', 'research', 'biology', 'university', 'psychology', 'economics', 'Engineering', 'sciences', 'technology', 'technical', 'science', 'mechanical', 'engineers', 'institute', 'mathematics', 'biomedical', 'physics', 'AccountingGraduate', 'CustomerSupply', 'Chain', 'chains', 'stores', 'store', 'supermarket', 'grocery', 'retail', 'retailer', 'restaurants', 'shop', 'supermarkets']
#
# None
# ['Commerce', 'trade', 'department', 'transportation', 'tourism', 'finance', 'industry', 'affairs', 'agriculture', 'business', 'bureau', 'Informatics', 'biomedical', 'neuroscience', 'cybernetics', 'sciences', 'bioinformatics', 'microbiology', 'humanities', 'robotics', 'nanotechnology', 'olympiad', 'Investec', 'lereah', 'calyon', 'bittles', 'numis', 'ehrenkrantz', 'ladwa', 'readerman', 'painewebber', 'pecoriello', 'hambrecht', 'Grad', 'bm-21', 'grads', 'mrkonjic', 'mrkonjić', 'katyusha', 'ib', 'rocket', '122mm', 'sipovo', 'rockets', 'Business', 'industry', 'companies', 'businesses', 'marketing', 'company', 'corporate', 'financial', 'market', 'investment', 'management', 'Programme', 'programmes', 'program', 'programs', 'project', 'bbc', 'development', 'projects', 'funding', 'educational', 'activities', 'Bachelor', 'doctorate', 'degree', 'bachelors', 'graduate', 'ph.d.', 'b.a.', 'undergraduate', 'graduated', 'phd', 'diploma', 'Tech', 'technology', 'electronics', 'computer', 'chip', 'big', 'business', 'texas', 'industrial', 'advanced', 'technological', 'Systems', 'system', 'technologies', 'equipment', 'technology', 'software', 'computer', 'devices', 'components', 'communications', 'communication', 'Computer', 'computers', 'software', 'technology', 'pc', 'hardware', 'internet', 'desktop', 'electronic', 'systems', 'computing', 'Science', 'sciences', 'physics', 'institute', 'mathematics', 'studies', 'research', 'biology', 'university', 'psychology', 'economics', 'Engineering', 'sciences', 'technology', 'technical', 'science', 'mechanical', 'engineers', 'institute', 'mathematics', 'biomedical', 'physics', 'InformationRequired', 'Fields', 'field', 'areas', 'natural', 'agricultural', 'well', 'projects', 'surrounding', 'farming', 'land', 'development', 'Study', 'studies', 'research', 'researchers', 'studying', 'scientific', 'institute', 'science', 'clinical', 'findings', 'analysis']
#
# None
# ['Improve', 'improving', 'enhance', 'improved', 'strengthen', 'maintain', 'develop', 'boost', 'expand', 'ensure', 'better', 'Nedbank', 'cosafa', 'twenty-20', 'vodacom', 'dunhill', 'absa', 'invitational', 'sundarbans', 'canada-russia', 'jeonju', 'everland', 'Financial', 'banking', 'corporate', 'economic', 'credit', 'investment', 'business', 'global', 'management', 'fund', 'banks', 'Quantitative', 'qualitative', 'empirical', 'analysis', 'methodology', 'analytical', 'methods', 'analyses', 'behavioral', 'descriptive', 'theoretical', 'Contribute', 'contributes', 'encourage', 'reduce', 'benefit', 'promote', 'enhance', 'improve', 'achieve', 'expand', 'accelerate', 'Training', 'preparation', 'skills', 'teaching', 'combat', 'program', 'trained', 'instructors', 'personnel', 'operations', 'courses', 'Management', 'financial', 'business', 'managers', 'investment', 'development', 'consulting', 'managing', 'marketing', 'corporate', 'asset', 'Quants', 'b-boys', 'paleoconservatives', 'moscovites', 'rishonim', 'mahatmas', 'objectivists', 'muckrakers', 'maquisards', 'bouchons', 'abelisaurids', 'Programme', 'programmes', 'program', 'programs', 'project', 'bbc', 'development', 'projects', 'funding', 'educational', 'activities', 'Econometrics', 'climatology', 'criminology', 'econometric', 'geomorphology', 'cybernetics', 'maplewood', 'geology', 'kisco', 'hydrogeology', 'microeconomics', 'Applied', 'apply', 'applying', 'application', 'using', 'used', 'obtained', 'applies', 'use', 'applications', 'methods', 'Risk', 'risks', 'danger', 'exposure', 'potential', 'cause', 'avoid', 'consequences', 'likelihood', 'serious', 'potentially', 'Mathematics', 'physics', 'mathematical', 'science', 'biology', 'chemistry', 'sociology', 'philosophy', 'humanities', 'linguistics', 'sciences', 'EngineeringRequired', 'Pure', 'essence', 'true', 'simple', 'organic', 'blend', 'unadulterated', 'purity', 'kind', 'mix', 'passion', 'Mathematics', 'physics', 'mathematical', 'science', 'biology', 'chemistry', 'sociology', 'philosophy', 'humanities', 'linguistics', 'sciences', 'Fields', 'field', 'areas', 'natural', 'agricultural', 'well', 'projects', 'surrounding', 'farming', 'land', 'development']
#
# ['The', 'this', 'part', 'one', 'of', 'same', 'first', 'on', 'its', 'as', 'that', 'Continuous', 'constant', 'continual', 'periodic', 'static', 'rapid', 'linear', 'continuation', 'normal', 'extensive', 'direct', 'Informatics', 'biomedical', 'neuroscience', 'cybernetics', 'sciences', 'bioinformatics', 'microbiology', 'humanities', 'robotics', 'nanotechnology', 'olympiad', 'Grad', 'bm-21', 'grads', 'mrkonjic', 'mrkonjić', 'katyusha', 'ib', 'rocket', '122mm', 'sipovo', 'rockets', 'Programme', 'programmes', 'program', 'programs', 'project', 'bbc', 'development', 'projects', 'funding', 'educational', 'activities', 'Computer', 'computers', 'software', 'technology', 'pc', 'hardware', 'internet', 'desktop', 'electronic', 'systems', 'computing', 'Learning', 'teaching', 'knowledge', 'experience', 'skills', 'learn', 'understanding', 'education', 'educational', 'lessons', 'studying', 'Science', 'sciences', 'physics', 'institute', 'mathematics', 'studies', 'research', 'biology', 'university', 'psychology', 'economics', 'Technology', 'technologies', 'computer', 'tech', 'software', 'systems', 'innovation', 'technological', 'engineering', 'research', 'computing', 'Information', 'data', 'knowledge', 'access', 'provided', 'intelligence', 'source', 'documents', 'web', 'internet', 'provide']
#
# None
# ['UnderstandPursues', 'Requirements', 'requirement', 'standards', 'regulations', 'required', 'rules', 'criteria', 'limits', 'guidelines', 'compliance', 'require', 'Team', 'teams', 'squad', 'football', 'players', 'coach', 'player', 'league', 'season', 'soccer', 'championship', 'Assurance', 'assurances', 'guarantee', 'satisfaction', 'trust', 'guarantees', 'guidance', 'clarity', 'adequate', 'assure', 'assessment', 'External', 'internal', 'structural', 'foreign', 'direct', 'and/or', 'current', 'system', 'affairs', 'budgetary', 'input', 'Quality', 'excellent', 'standards', 'performance', 'good', 'better', 'improve', 'lack', 'product', 'efficiency', 'well', 'Accounting', 'auditing', 'audit', 'financial', 'auditors', 'practices', 'bookkeeping', 'management', 'corporate', 'disclosure', 'firms']
#
# None
# None
# ['South', 'north', 'west', 'east', 'western', 'southern', 'southeast', 'africa', 'korea', 'northern', 'northeast', 'AfricaInstrumentation', 'Telecommunication', 'telecommunications', 'telecoms', 'telecom', 'communications', 'wireless', 'communication', 'telephony', 'infrastructure', 'services', 'provider', 'Competencies', 'competences', 'competence', 'competency', 'self-discipline', 'strengths', 'methodologies', 'qualifications', 'teamwork', 'proficiencies', 'abilities', 'Opportunities', 'opportunity', 'possibilities', 'advantages', 'advantage', 'benefit', 'experience', 'innovation', 'resources', 'development', 'encourage', 'Human', 'animal', 'rights', 'humans', 'animals', 'body', 'nature', 'beings', 'organization', 'scientific', 'common', 'Management', 'financial', 'business', 'managers', 'investment', 'development', 'consulting', 'managing', 'marketing', 'corporate', 'asset', 'Tech', 'technology', 'electronics', 'computer', 'chip', 'big', 'business', 'texas', 'industrial', 'advanced', 'technological', 'Resource', 'resources', 'conservation', 'environment', 'development', 'enterprise', 'natural', 'management', 'energy', 'technology', 'biodiversity', 'Control', 'controls', 'controlled', 'power', 'controlling', 'system', 'security', 'own', 'authority', 'rule', 'forces', 'Electrical', 'mechanical', 'electric', 'electricity', 'machinery', 'components', 'engineering', 'wiring', 'plumbing', 'equipment', 'generator', 'Industrial', 'manufacturing', 'industries', 'sector', 'sectors', 'agricultural', 'construction', 'machinery', 'textile', 'industry', 'mining', 'Graduate', 'undergraduate', 'graduating', 'harvard', 'enrolled', 'graduated', 'college', 'graduates', 'faculty', 'university', 'yale', 'Completed', 'completion', 'completing', 'complete', 'first', 'construction', 'commenced', 'finished', 'later', 'project', 'prior', 'Literacy', 'numeracy', 'education', 'educational', 'illiteracy', 'math', 'curriculum', 'proficiency', 'learners', 'awareness', 'enrollment', 'Programme', 'programmes', 'program', 'programs', 'project', 'bbc', 'development', 'projects', 'funding', 'educational', 'activities', 'Our', 'their', 'my', 'your', 'own', 'we', 'way', 'what', 'good', 'whatever', 'need', 'Computer', 'computers', 'software', 'technology', 'pc', 'hardware', 'internet', 'desktop', 'electronic', 'systems', 'computing', 'Social', 'education', 'political', 'cultural', 'welfare', 'educational', 'reform', 'health', 'public', 'environment', 'environmental', 'Skills', 'skill', 'abilities', 'talents', 'expertise', 'learning', 'ability', 'knowledge', 'experience', 'talent', 'techniques', 'Trainee', 'apprentice', 'full-time', 'part-time', 'janitor', 'technician', 'recruiter', 'trainees', 'paralegal', 'instructor', 'tutor', 'Honours', 'honors', 'honour', 'bestowed', 'knighthood', 'awarded', 'knighted', 'honorary', 'diploma', 'prizes', 'conferred', 'Chemical', 'chemicals', 'biological', 'toxic', 'materials', 'biochemical', 'compounds', 'industrial', 'components', 'nuclear', 'pesticides', 'Mechanical', 'electrical', 'engineering', 'hydraulic', 'mechanics', 'technical', 'hydraulics', 'physics', 'structural', 'components', 'design', 'Structured', 'customized', 'unstructured', 'integrated', 'flexible', 'combining', 'defined', 'structuring', 'hierarchical', 'tailored', 'coherent', 'Marketing', 'advertising', 'business', 'merchandising', 'product', 'management', 'corporate', 'brand', 'company', 'strategy', 'creative', 'Sales', 'retail', 'revenue', 'profit', 'earnings', 'consumer', 'profits', 'product', 'revenues', 'market', 'selling', 'Trainees', 'instructors', 'cadets', 'recruits', 'apprentices', 'sergeants', 'graduates', 'undergraduates', 'tutors', 'interns', 'recruiters', 'Bachelor', 'doctorate', 'degree', 'bachelors', 'graduate', 'ph.d.', 'b.a.', 'undergraduate', 'graduated', 'phd', 'diploma', 'Resources', 'resource', 'energy', 'environment', 'development', 'needs', 'natural', 'expertise', 'provide', 'infrastructure', 'reserves', 'Arts', 'art', 'academy', 'sci ...
#
# None
# ['Chemical', 'chemicals', 'biological', 'toxic', 'materials', 'biochemical', 'compounds', 'industrial', 'components', 'nuclear', 'pesticides', 'Graduate', 'undergraduate', 'graduating', 'harvard', 'enrolled', 'graduated', 'college', 'graduates', 'faculty', 'university', 'yale', 'Qualification', 'qualifying', 'qualify', 'qualified', 'qualifiers', 'play-off', 'qualifications', 'champions', 'uefa', 'tournament', 'championship', 'Programme', 'programmes', 'program', 'programs', 'project', 'bbc', 'development', 'projects', 'funding', 'educational', 'activities', 'Must', 'should', 'cannot', 'would', 'need', 'can', 'will', 'not', 'could', 'be', 'come', 'Engineering', 'sciences', 'technology', 'technical', 'science', 'mechanical', 'engineers', 'institute', 'mathematics', 'biomedical', 'physics', 'IndustryStellenbosch']
#
# None
# ['South', 'north', 'west', 'east', 'western', 'southern', 'southeast', 'africa', 'korea', 'northern', 'northeast', 'AfricaWholesale', 'Institution', 'institutions', 'society', 'institute', 'established', 'private', 'university', 'foundation', 'academic', 'education', 'educational', 'Group', 'groups', 'based', 'members', 'organization', 'led', 'which', 'formed', 'alliance', 'joined', 'called', 'Industrial', 'manufacturing', 'industries', 'sector', 'sectors', 'agricultural', 'construction', 'machinery', 'textile', 'industry', 'mining', 'Digital', 'electronic', 'analog', 'video', 'audio', 'multimedia', 'computer', 'wireless', 'interactive', 'internet', 'computers', 'Education', 'educational', 'schools', 'teaching', 'curriculum', 'programs', 'social', 'health', 'school', 'academic', 'welfare', 'Human', 'animal', 'rights', 'humans', 'animals', 'body', 'nature', 'beings', 'organization', 'scientific', 'common', 'Marketing', 'advertising', 'business', 'merchandising', 'product', 'management', 'corporate', 'brand', 'company', 'strategy', 'creative', 'Business', 'industry', 'companies', 'businesses', 'marketing', 'company', 'corporate', 'financial', 'market', 'investment', 'management', 'Perform', 'performed', 'performing', 'performs', 'participate', 'live', 'undergo', 'dance', 'sing', 'required', 'able', 'Administration', 'government', 'policy', 'bush', 'congress', 'officials', 'clinton', 'office', 'department', 'federal', 'washington', 'Execute', 'executing', 'executed', 'executes', 'execution', 'accountable', 'instructions', 'respond', 'implement', 'proceed', 'faithfully', 'Management', 'financial', 'business', 'managers', 'investment', 'development', 'consulting', 'managing', 'marketing', 'corporate', 'asset', 'Required', 'require', 'requires', 'requiring', 'necessary', 'requirement', 'requirements', 'allow', 'needed', 'provide', 'must', 'Psychology', 'sociology', 'philosophy', 'anthropology', 'biology', 'psychiatry', 'neuroscience', 'science', 'professor', 'studies', 'economics', 'Resource', 'resources', 'conservation', 'environment', 'development', 'enterprise', 'natural', 'management', 'energy', 'technology', 'biodiversity', 'Project', 'projects', 'development', 'program', 'plan', 'construction', 'plans', 'work', 'initiative', 'part', 'build', 'Retail', 'sales', 'retailers', 'consumer', 'stores', 'market', 'retailing', 'wholesale', 'store', 'businesses', 'retailer']
# None
# ['Commerce', 'trade', 'department', 'transportation', 'tourism', 'finance', 'industry', 'affairs', 'agriculture', 'business', 'bureau', 'Industrial', 'manufacturing', 'industries', 'sector', 'sectors', 'agricultural', 'construction', 'machinery', 'textile', 'industry', 'mining', 'Responsibilities', 'duties', 'responsibility', 'obligations', 'tasks', 'matters', 'fulfill', 'priorities', 'delegated', 'objectives', 'entrusted', 'Business', 'industry', 'companies', 'businesses', 'marketing', 'company', 'corporate', 'financial', 'market', 'investment', 'management', 'Finance', 'banking', 'foreign', 'minister', 'financial', 'commerce', 'investment', 'reform', 'government', 'fund', 'affairs', 'Management', 'financial', 'business', 'managers', 'investment', 'development', 'consulting', 'managing', 'marketing', 'corporate', 'asset', 'Systems', 'system', 'technologies', 'equipment', 'technology', 'software', 'computer', 'devices', 'components', 'communications', 'communication', 'Deliver', 'delivering', 'delivered', 'provide', 'carry', 'delivers', 'promised', 'bring', 'send', 'promise', 'produce', 'Computer', 'computers', 'software', 'technology', 'pc', 'hardware', 'internet', 'desktop', 'electronic', 'systems', 'computing', 'Psychology', 'sociology', 'philosophy', 'anthropology', 'biology', 'psychiatry', 'neuroscience', 'science', 'professor', 'studies', 'economics', 'Science', 'sciences', 'physics', 'institute', 'mathematics', 'studies', 'research', 'biology', 'university', 'psychology', 'economics', 'Information', 'data', 'knowledge', 'access', 'provided', 'intelligence', 'source', 'documents', 'web', 'internet', 'provide', 'Accounting', 'auditing', 'audit', 'financial', 'auditors', 'practices', 'bookkeeping', 'management', 'corporate', 'disclosure', 'firms', 'ParticipationMathsActuarial', 'Science', 'sciences', 'physics', 'institute', 'mathematics', 'studies', 'research', 'biology', 'university', 'psychology', 'economics', 'Participate', 'participating', 'attend', 'join', 'participation', 'organize', 'participated', 'compete', 'engage', 'enter', 'continue']
#
# None
# ['GqeberhaInternational', 'Skills', 'skill', 'abilities', 'talents', 'expertise', 'learning', 'ability', 'knowledge', 'experience', 'talent', 'techniques', 'Durban', 'johannesburg', 'pretoria', 'bloemfontein', 'pietermaritzburg', 'galle', 'polokwane', 'newlands', 'cape', 'auckland', 'christchurch', 'Group', 'groups', 'based', 'members', 'organization', 'led', 'which', 'formed', 'alliance', 'joined', 'called', 'The', 'this', 'part', 'one', 'of', 'same', 'first', 'on', 'its', 'as', 'that', 'Adapting', 'adapt', 'evolving', 'devising', 'designing', 'innovating', 'adjusting', 'inventing', 'integrating', 'perfecting', 'experimenting', 'Business', 'industry', 'companies', 'businesses', 'marketing', 'company', 'corporate', 'financial', 'market', 'investment', 'management', 'Chain', 'chains', 'stores', 'store', 'supermarket', 'grocery', 'retail', 'retailer', 'restaurants', 'shop', 'supermarkets', 'Quantitative', 'qualitative', 'empirical', 'analysis', 'methodology', 'analytical', 'methods', 'analyses', 'behavioral', 'descriptive', 'theoretical', 'Shoprite', 'wegmans', 'dfs', 'safeway', 'fujisankei', 'funai', 'takefuji', 'lpga', 'crowne', 'mizuno', 'maurier', 'Trade', 'export', 'economic', 'trading', 'commerce', 'cooperation', 'exports', 'industry', 'wto', 'market', 'exchange', 'Management', 'financial', 'business', 'managers', 'investment', 'development', 'consulting', 'managing', 'marketing', 'corporate', 'asset', 'Enterprising', 'industrious', 'resourceful', 'adventurous', 'hardworking', 'astute', 'hard-working', 'adventuresome', 'skilful', 'inquisitive', 'headstrong', 'Supply', 'supplies', 'fuel', 'electricity', 'demand', 'shortage', 'oil', 'capacity', 'food', 'gasoline', 'equipment', 'Companies', 'firms', 'businesses', 'company', 'corporations', 'industry', 'business', 'manufacturers', 'makers', 'venture', 'industries']
#
# ['Theory', 'theories', 'concept', 'evolution', 'hypothesis', 'concepts', 'theoretical', 'notion', 'logic', 'philosophy', 'analysis', 'Accounting', 'auditing', 'audit', 'financial', 'auditors', 'practices', 'bookkeeping', 'management', 'corporate', 'disclosure', 'firms']
#
# ['Danone', 'nestle', 'aventis', "l'oreal", 'wahaha', 'sanofi', 'inbev', 'pepsico', 'novartis', 'interbrew', 'groupe', 'Operations', 'operation', 'unit', 'operating', 'personnel', 'military', 'services', 'command', 'operational', 'units', 'force']
#
# None
# ['AccountingStandard', 'Graduate', 'undergraduate', 'graduating', 'harvard', 'enrolled', 'graduated', 'college', 'graduates', 'faculty', 'university', 'yale', 'Honours', 'honors', 'honour', 'bestowed', 'knighthood', 'awarded', 'knighted', 'honorary', 'diploma', 'prizes', 'conferred', 'Bank', 'banks', 'banking', 'credit', 'investment', 'financial', 'securities', 'lending', 'funds', 'ubs', 'finance', 'Theory', 'theories', 'concept', 'evolution', 'hypothesis', 'concepts', 'theoretical', 'notion', 'logic', 'philosophy', 'analysis', 'Board', 'commission', 'committee', 'directors', 'executive', 'council', 'panel', 'boards', 'chairman', 'commissioners', 'trustees', 'Diploma', 'postgraduate', 'certificate', 'post-graduate', 'diplomas', 'doctorate', 'phd', 'baccalaureate', 'undergraduate', 'doctoral', 'bachelor', 'Postgraduate', 'post-graduate', 'undergraduate', 'diploma', 'doctoral', 'graduate', 'phd', 'courses', 'doctorate', 'ph.d', 'postdoctoral', 'Accounting', 'auditing', 'audit', 'financial', 'auditors', 'practices', 'bookkeeping', 'management', 'corporate', 'disclosure', 'firms']
#
# None
# ['AspenCommerce', 'Graduate', 'undergraduate', 'graduating', 'harvard', 'enrolled', 'graduated', 'college', 'graduates', 'faculty', 'university', 'yale', 'Opportunities', 'opportunity', 'possibilities', 'advantages', 'advantage', 'benefit', 'experience', 'innovation', 'resources', 'development', 'encourage', 'Human', 'animal', 'rights', 'humans', 'animals', 'body', 'nature', 'beings', 'organization', 'scientific', 'common', 'Business', 'industry', 'companies', 'businesses', 'marketing', 'company', 'corporate', 'financial', 'market', 'investment', 'management', 'Committed', 'committing', 'commit', 'responsible', 'crimes', 'charged', 'involvement', 'involved', 'criminal', 'guilty', 'actions', 'Capital', 'city', 'central', 'investment', 'government', 'cities', 'outside', 'in', 'bank', 'outskirts', 'northeast', 'Management', 'financial', 'business', 'managers', 'investment', 'development', 'consulting', 'managing', 'marketing', 'corporate', 'asset', 'Aspen', 'vail', 'cedar', 'breckenridge', 'sedona', 'colo.', 'laurel', 'ski', 'cottonwood', 'telluride', 'boulder', 'Programme', 'programmes', 'program', 'programs', 'project', 'bbc', 'development', 'projects', 'funding', 'educational', 'activities', 'Health', 'care', 'medical', 'healthcare', 'education', 'welfare', 'environmental', 'nutrition', 'aids', 'prevention', 'hospitals', 'Computer', 'computers', 'software', 'technology', 'pc', 'hardware', 'internet', 'desktop', 'electronic', 'systems', 'computing', 'Internship', 'apprenticeship', 'internships', 'sabbatical', 'residencies', 'post-graduate', 'semester', 'undergraduate', 'vocational', 'secretarial', 'part-time', 'Degree', 'bachelor', 'doctorate', 'graduate', 'degrees', 'undergraduate', 'graduated', 'ph.d.', 'graduating', 'phd', 'b.a.', 'Diploma', 'postgraduate', 'certificate', 'post-graduate', 'diplomas', 'doctorate', 'phd', 'baccalaureate', 'undergraduate', 'doctoral', 'bachelor', 'Science', 'sciences', 'physics', 'institute', 'mathematics', 'studies', 'research', 'biology', 'university', 'psychology', 'economics', 'Resource', 'resources', 'conservation', 'environment', 'development', 'enterprise', 'natural', 'management', 'energy', 'technology', 'biodiversity']
#
# ['Geology', 'mineralogy', 'zoology', 'geography', 'archaeology', 'paleontology', 'botany', 'geomorphology', 'archeology', 'anthropology', 'biology', 'Chemical', 'chemicals', 'biological', 'toxic', 'materials', 'biochemical', 'compounds', 'industrial', 'components', 'nuclear', 'pesticides', 'Trainee', 'apprentice', 'full-time', 'part-time', 'janitor', 'technician', 'recruiter', 'trainees', 'paralegal', 'instructor', 'tutor', 'Industrial', 'manufacturing', 'industries', 'sector', 'sectors', 'agricultural', 'construction', 'machinery', 'textile', 'industry', 'mining', 'Graduate', 'undergraduate', 'graduating', 'harvard', 'enrolled', 'graduated', 'college', 'graduates', 'faculty', 'university', 'yale', 'Operations', 'operation', 'unit', 'operating', 'personnel', 'military', 'services', 'command', 'operational', 'units', 'force', 'Bsc', 'hons', 'b.sc', 'phd', 'ph.d', 'm.sc', 'bachelor', 'mphil', 'doctorate', 'b.a.', 'bachelors', 'Engineer', 'engineers', 'technician', 'mechanic', 'engineering', 'architect', 'contractor', 'officer', 'worked', 'master', 'chemist', 'Eng', 'fra', 'aus', 'capt', 'saracens', 'leicester', 'rsa', 'esp', 'harlequins', '/', 'gareth', 'Engineering', 'sciences', 'technology', 'technical', 'science', 'mechanical', 'engineers', 'institute', 'mathematics', 'biomedical', 'physics', 'Technology', 'technologies', 'computer', 'tech', 'software', 'systems', 'innovation', 'technological', 'engineering', 'research', 'computing', 'Opportunties', 'opportunites', 'opportunies', 'legals', 'intiatives', 'propects', 'cost-savings', 'character-building', 'powerplays', 'taskings', 'possibilites']
#
# None
# ['AccountingOpportunities', 'Post', 'office', 'times', 'news', 'end', 'following', 'new', 'time', 'first', 'newspaper', 'recently', 'Management', 'financial', 'business', 'managers', 'investment', 'development', 'consulting', 'managing', 'marketing', 'corporate', 'asset', 'Mathematics', 'physics', 'mathematical', 'science', 'biology', 'chemistry', 'sociology', 'philosophy', 'humanities', 'linguistics', 'sciences', 'Technology', 'technologies', 'computer', 'tech', 'software', 'systems', 'innovation', 'technological', 'engineering', 'research', 'computing', 'Standard', 'standards', 'basic', 'system', 'definition', 'example', 'same', 'code', 'type', 'use', 'common', 'Graduate', 'undergraduate', 'graduating', 'harvard', 'enrolled', 'graduated', 'college', 'graduates', 'faculty', 'university', 'yale', 'Investment', 'investments', 'fund', 'asset', 'financial', 'firms', 'equity', 'funds', 'business', 'portfolio', 'sector', 'Statistics', 'figures', 'report', 'data', 'statistic', 'bureau', 'according', 'estimates', 'statistical', 'survey', 'gdp', 'Bank', 'banks', 'banking', 'credit', 'investment', 'financial', 'securities', 'lending', 'funds', 'ubs', 'finance', 'Math', 'mathematics', 'maths', 'grade', 'classroom', 'graders', 'curriculum', 'grades', 'exams', 'teacher', 'literacy', 'Programme', 'programmes', 'program', 'programs', 'project', 'bbc', 'development', 'projects', 'funding', 'educational', 'activities', 'Postgraduate', 'post-graduate', 'undergraduate', 'diploma', 'doctoral', 'graduate', 'phd', 'courses', 'doctorate', 'ph.d', 'postdoctoral', 'Honours', 'honors', 'honour', 'bestowed', 'knighthood', 'awarded', 'knighted', 'honorary', 'diploma', 'prizes', 'conferred', 'Theory', 'theories', 'concept', 'evolution', 'hypothesis', 'concepts', 'theoretical', 'notion', 'logic', 'philosophy', 'analysis', 'Applied', 'apply', 'applying', 'application', 'using', 'used', 'obtained', 'applies', 'use', 'applications', 'methods', 'Data', 'information', 'analysis', 'tracking', 'database', 'system', 'computer', 'statistics', 'systems', 'applications', 'numbers', 'Diploma', 'postgraduate', 'certificate', 'post-graduate', 'diplomas', 'doctorate', 'phd', 'baccalaureate', 'undergraduate', 'doctoral', 'bachelor', 'Economics', 'sociology', 'professor', 'science', 'philosophy', 'psychology', 'mathematics', 'sciences', 'physics', 'harvard', 'institute', 'Board', 'commission', 'committee', 'directors', 'executive', 'council', 'panel', 'boards', 'chairman', 'commissioners', 'trustees', 'Science', 'sciences', 'physics', 'institute', 'mathematics', 'studies', 'research', 'biology', 'university', 'psychology', 'economics', 'Engineering', 'sciences', 'technology', 'technical', 'science', 'mechanical', 'engineers', 'institute', 'mathematics', 'biomedical', 'physics', 'Accounting', 'auditing', 'audit', 'financial', 'auditors', 'practices', 'bookkeeping', 'management', 'corporate', 'disclosure', 'firms']
#
# None
# ['Terminals', 'ports', 'terminal', 'airports', 'container', 'docks', 'shipping', 'seaports', 'tankers', 'heathrow', 'pipelines', 'Port', 'ports', 'coast', 'city', 'ship', 'harbour', 'coastal', 'airport', 'shipping', 'seaport', 'terminal', 'TransnetProfessional', 'Time', 'when', 'this', 'before', 'but', 'only', 'one', '.', 'same', 'first', 'days', 'Audit', 'auditing', 'audits', 'auditors', 'auditor', 'accounting', 'oversight', 'review', 'evaluation', 'appraisal', 'irs', 'Internal', 'external', 'ongoing', 'security', 'problems', 'investigations', 'control', 'political', 'investigation', 'current', 'source', 'Training', 'preparation', 'skills', 'teaching', 'combat', 'program', 'trained', 'instructors', 'personnel', 'operations', 'courses', 'General', 'secretary', 'chief', 'gen.', 'president', 'vice', 'office', 'deputy', 'department', 'commander', 'led', 'Programme', 'programmes', 'program', 'programs', 'project', 'bbc', 'development', 'projects', 'funding', 'educational', 'activities', 'Office', 'offices', 'house', 'department', 'administration', 'post', 'government', 'public', 'official', 'officials', 'headquarters', 'Communication', 'communications', 'systems', 'services', 'technology', 'knowledge', 'information', 'learning', 'interaction', 'navigation', 'connections', 'Accounting', 'auditing', 'audit', 'financial', 'auditors', 'practices', 'bookkeeping', 'management', 'corporate', 'disclosure', 'firms', 'Young', 'younger', 'fellow', 'man', 'children', 'boys', 'talented', 'girls', 'teenage', 'child', 'youngsters']
#
# None
# None
# ['Head', 'heads', 'headed', 'chief', 'body', 'assistant', 'chair', 'hand', 'former', 'senior', 'hands', 'OfficePower', 'Financial', 'banking', 'corporate', 'economic', 'credit', 'investment', 'business', 'global', 'management', 'fund', 'banks', 'Management', 'financial', 'business', 'managers', 'investment', 'development', 'consulting', 'managing', 'marketing', 'corporate', 'asset', 'Risk', 'risks', 'danger', 'exposure', 'potential', 'cause', 'avoid', 'consequences', 'likelihood', 'serious', 'potentially', 'Technology', 'technologies', 'computer', 'tech', 'software', 'systems', 'innovation', 'technological', 'engineering', 'research', 'computing', 'Information', 'data', 'knowledge', 'access', 'provided', 'intelligence', 'source', 'documents', 'web', 'internet', 'provide', 'Project', 'projects', 'development', 'program', 'plan', 'construction', 'plans', 'work', 'initiative', 'part', 'build', 'Treasury', 'bond', 'finance', 'bonds', 'yields', 'geithner', 'federal', 'greenspan', 'funds', 'securities', 'borrowing', 'International', 'european', 'global', 'world', 'nations', 'regional', 'united', 'national', 'for', 'based', 'union', 'Investment', 'investments', 'fund', 'asset', 'financial', 'firms', 'equity', 'funds', 'business', 'portfolio', 'sector', 'Policy', 'policies', 'administration', 'reform', 'strategy', 'economic', 'issue', 'agenda', 'approach', 'change', 'stance', 'Analysis', 'analyses', 'data', 'research', 'study', 'methods', 'scientific', 'methodology', 'assessment', 'studies', 'theory', 'Relations', 'ties', 'cooperation', 'relationship', 'bilateral', 'diplomatic', 'friendship', 'contacts', 'dialogue', 'strengthen', 'political', 'Operational', 'command', 'operations', 'tactical', 'operating', 'maintenance', 'strategic', 'capability', 'training', 'personnel', 'logistics', 'Business', 'industry', 'companies', 'businesses', 'marketing', 'company', 'corporate', 'financial', 'market', 'investment', 'management', 'Academy', 'arts', 'school', 'institute', 'college', 'sciences', 'university', 'graduate', 'science', 'graduating', 'graduated', 'Point', 'points', 'one', 'time', 'just', 'close', 'this', 'only', 'same', 'difference', 'end', 'Research', 'studies', 'study', 'scientific', 'institute', 'science', 'researchers', 'analysis', 'development', 'laboratory', 'researcher', 'Econometrics', 'climatology', 'criminology', 'econometric', 'geomorphology', 'cybernetics', 'maplewood', 'geology', 'kisco', 'hydrogeology', 'microeconomics', 'PortfolioLawAnalysis', 'Quantitative', 'qualitative', 'empirical', 'analysis', 'methodology', 'analytical', 'methods', 'analyses', 'behavioral', 'descriptive', 'theoretical']
#
# None
# None
# ['Geology', 'mineralogy', 'zoology', 'geography', 'archaeology', 'paleontology', 'botany', 'geomorphology', 'archeology', 'anthropology', 'biology', 'Forensic', 'forensics', 'pathologist', 'investigator', 'examination', 'pathologists', 'investigators', 'examined', 'ballistics', 'detectives', 'expert', 'Opportunities', 'opportunity', 'possibilities', 'advantages', 'advantage', 'benefit', 'experience', 'innovation', 'resources', 'development', 'encourage', 'Financial', 'banking', 'corporate', 'economic', 'credit', 'investment', 'business', 'global', 'management', 'fund', 'banks', 'Sustainability', 'sustainable', 'governance', 'innovation', 'environmental', 'ecological', 'entrepreneurship', 'biodiversity', 'competitiveness', 'conservation', 'excellence', 'Management', 'financial', 'business', 'managers', 'investment', 'development', 'consulting', 'managing', 'marketing', 'corporate', 'asset', 'Crime', 'criminal', 'crimes', 'murder', 'trafficking', 'terrorism', 'homicide', 'corruption', 'criminals', 'gang', 'dealing', 'Undergraduate', 'graduate', 'postgraduate', 'doctoral', 'post-graduate', 'faculty', 'undergraduates', 'graduates', 'enrolled', 'academic', 'bachelor', 'Services', 'service', 'transportation', 'communications', 'business', 'access', 'communication', 'provider', 'private', 'providers', 'public', 'Africa', 'african', 'continent', 'asia', 'zimbabwe', 'south', 'australia', 'kenya', 'nations', 'africans', 'countries', 'Risk', 'risks', 'danger', 'exposure', 'potential', 'cause', 'avoid', 'consequences', 'likelihood', 'serious', 'potentially', 'Mathematics', 'physics', 'mathematical', 'science', 'biology', 'chemistry', 'sociology', 'philosophy', 'humanities', 'linguistics', 'sciences', 'Technology', 'technologies', 'computer', 'tech', 'software', 'systems', 'innovation', 'technological', 'engineering', 'research', 'computing', 'Information', 'data', 'knowledge', 'access', 'provided', 'intelligence', 'source', 'documents', 'web', 'internet', 'provide', 'Commerce', 'trade', 'department', 'transportation', 'tourism', 'finance', 'industry', 'affairs', 'agriculture', 'business', 'bureau', 'Industrial', 'manufacturing', 'industries', 'sector', 'sectors', 'agricultural', 'construction', 'machinery', 'textile', 'industry', 'mining', 'Graduate', 'undergraduate', 'graduating', 'harvard', 'enrolled', 'graduated', 'college', 'graduates', 'faculty', 'university', 'yale', 'Mathematical', 'theoretical', 'computational', 'mathematics', 'physics', 'equations', 'computation', 'empirical', 'theory', 'numerical', 'geometry', 'Geography', 'sociology', 'geology', 'mathematics', 'anthropology', 'biology', 'philosophy', 'economics', 'demography', 'ecology', 'linguistics', 'Legal', 'law', 'constitutional', 'rights', 'judicial', 'case', 'political', 'laws', 'issue', 'court', 'civil', 'Statistics', 'figures', 'report', 'data', 'statistic', 'bureau', 'according', 'estimates', 'statistical', 'survey', 'gdp', 'Analytics', 'consultancy', 'visualization', 'gartner', 'metrics', 'consulting', 'netratings', 'forrester', 'capgemini', 'predictive', 'associates', 'Governance', 'transparency', 'accountability', 'sustainability', 'management', 'reform', 'framework', 'reforms', 'stability', 'macroeconomic', 'policies', 'Controls', 'control', 'controlled', 'controlling', 'power', 'restrictions', 'system', 'allows', 'grip', 'limits', 'regulation', 'Com', 'dot', 'harrynytimes', 'e', 'telegram', 'pager', 'nn', 'coms', 'web', 'berrisnytimes', 'internet', 'Programme', 'programmes', 'program', 'programs', 'project', 'bbc', 'development', 'projects', 'funding', 'educational', 'activities', 'Assurance', 'assurances', 'guarantee', 'satisfaction', 'trust', 'guarantees', 'guidance', 'clarity', 'adequate', 'assure', 'assessment', 'Computer', 'computers', 'software', 'technology', 'pc', 'hardware', 'internet', 'desktop', 'electronic', 'systems', 'computing', 'Bcom', 'bsba', 'btech', 'bmus', 'b.com', 'b.b.a.', 'ed.d', 'bsee', 'm.b.a', 'j.s.d.', 's.j.d.', 'Social', 'education', ' ...
# ['Import', 'export', 'imports', 'exports', 'imported', 'tariffs', 'goods', 'importing', 'tariff', 'importation', 'quotas', 'Internal', 'external', 'ongoing', 'security', 'problems', 'investigations', 'control', 'political', 'investigation', 'current', 'source', 'Research', 'studies', 'study', 'scientific', 'institute', 'science', 'researchers', 'analysis', 'development', 'laboratory', 'researcher', 'Export', 'import', 'exports', 'imports', 'goods', 'exporting', 'trade', 'output', 'demand', 'products', 'imported', 'Cleansing', 'massacres', 'genocide', 'atrocities', 'bloodletting', 'extermination', 'genocidal', 'repression', 'systematic', 'albanians', 'ritual', 'Com', 'dot', 'harrynytimes', 'e', 'telegram', 'pager', 'nn', 'coms', 'web', 'berrisnytimes', 'internet', 'External', 'internal', 'structural', 'foreign', 'direct', 'and/or', 'current', 'system', 'affairs', 'budgetary', 'input', 'Market', 'markets', 'stock', 'prices', 'stocks', 'investors', 'retail', 'business', 'consumer', 'trading', 'price', 'Data', 'information', 'analysis', 'tracking', 'database', 'system', 'computer', 'statistics', 'systems', 'applications', 'numbers', 'Science', 'sciences', 'physics', 'institute', 'mathematics', 'studies', 'research', 'biology', 'university', 'psychology', 'economics', 'Communication', 'communications', 'systems', 'services', 'technology', 'knowledge', 'information', 'learning', 'interaction', 'navigation', 'connections']
#
# None
# None
# ['Johannesburg', 'pretoria', 'harare', 'durban', 'nairobi', 'soweto', 'sydney', 'perth', 'bangkok', 'sandton', 'bulawayo', 'GautengInformatics', 'Financial', 'banking', 'corporate', 'economic', 'credit', 'investment', 'business', 'global', 'management', 'fund', 'banks', 'Management', 'financial', 'business', 'managers', 'investment', 'development', 'consulting', 'managing', 'marketing', 'corporate', 'asset', 'Risk', 'risks', 'danger', 'exposure', 'potential', 'cause', 'avoid', 'consequences', 'likelihood', 'serious', 'potentially', 'Technology', 'technologies', 'computer', 'tech', 'software', 'systems', 'innovation', 'technological', 'engineering', 'research', 'computing', 'Information', 'data', 'knowledge', 'access', 'provided', 'intelligence', 'source', 'documents', 'web', 'internet', 'provide', 'Industrial', 'manufacturing', 'industries', 'sector', 'sectors', 'agricultural', 'construction', 'machinery', 'textile', 'industry', 'mining', 'Audit', 'auditing', 'audits', 'auditors', 'auditor', 'accounting', 'oversight', 'review', 'evaluation', 'appraisal', 'irs', 'Computer', 'computers', 'software', 'technology', 'pc', 'hardware', 'internet', 'desktop', 'electronic', 'systems', 'computing', 'Dimension', 'dimensions', 'element', 'dimensional', 'complexity', 'sphere', 'context', 'spatial', 'aspect', 'definition', 'infinite', 'Sciences', 'science', 'institute', 'humanities', 'engineering', 'physics', 'biology', 'chemistry', 'mathematics', 'academy', 'arts', 'Chain', 'chains', 'stores', 'store', 'supermarket', 'grocery', 'retail', 'retailer', 'restaurants', 'shop', 'supermarkets', 'Accountancy', 'auditing', 'actuarial', 'accountants', 'deloitte', 'pricewaterhousecoopers', 'profession', 'self-financing', 'accounting', 'professions', 'm.b.a.', 'Data', 'information', 'analysis', 'tracking', 'database', 'system', 'computer', 'statistics', 'systems', 'applications', 'numbers', 'Logistics', 'logistic', 'operations', 'logistical', 'transport', 'materiel', 'warehousing', 'transportation', 'aviation', 'operational', 'maintenance', 'Chartered', 'airline', 'operated', 'airlines', 'charter', 'boarded', 'aboard', 'flight', 'carrier', 'hijacked', 'flying', 'Systems', 'system', 'technologies', 'equipment', 'technology', 'software', 'computer', 'devices', 'components', 'communications', 'communication', 'Eng', 'fra', 'aus', 'capt', 'saracens', 'leicester', 'rsa', 'esp', 'harlequins', '/', 'gareth', 'Supply', 'supplies', 'fuel', 'electricity', 'demand', 'shortage', 'oil', 'capacity', 'food', 'gasoline', 'equipment', 'Science', 'sciences', 'physics', 'institute', 'mathematics', 'studies', 'research', 'biology', 'university', 'psychology', 'economics', 'AccountingRequired', 'Fields', 'field', 'areas', 'natural', 'agricultural', 'well', 'projects', 'surrounding', 'farming', 'land', 'development']
#
# None
# ['International', 'european', 'global', 'world', 'nations', 'regional', 'united', 'national', 'for', 'based', 'union', 'Skills', 'skill', 'abilities', 'talents', 'expertise', 'learning', 'ability', 'knowledge', 'experience', 'talent', 'techniques', 'Durban', 'johannesburg', 'pretoria', 'bloemfontein', 'pietermaritzburg', 'galle', 'polokwane', 'newlands', 'cape', 'auckland', 'christchurch', 'Group', 'groups', 'based', 'members', 'organization', 'led', 'which', 'formed', 'alliance', 'joined', 'called', 'The', 'this', 'part', 'one', 'of', 'same', 'first', 'on', 'its', 'as', 'that', 'Gqeberha', 'Business', 'industry', 'companies', 'businesses', 'marketing', 'company', 'corporate', 'financial', 'market', 'investment', 'management', 'Chain', 'chains', 'stores', 'store', 'supermarket', 'grocery', 'retail', 'retailer', 'restaurants', 'shop', 'supermarkets', 'Quantitative', 'qualitative', 'empirical', 'analysis', 'methodology', 'analytical', 'methods', 'analyses', 'behavioral', 'descriptive', 'theoretical', 'Shoprite', 'wegmans', 'dfs', 'safeway', 'fujisankei', 'funai', 'takefuji', 'lpga', 'crowne', 'mizuno', 'maurier', 'Trade', 'export', 'economic', 'trading', 'commerce', 'cooperation', 'exports', 'industry', 'wto', 'market', 'exchange', 'Centurion', 'kingsmead', 'headingley', 'supersport', 'edgbaston', 'gabba', 'bloemfontein', 'scoreboard', 'newlands', 'dayer', 'odi', 'Management', 'financial', 'business', 'managers', 'investment', 'development', 'consulting', 'managing', 'marketing', 'corporate', 'asset', 'Supply', 'supplies', 'fuel', 'electricity', 'demand', 'shortage', 'oil', 'capacity', 'food', 'gasoline', 'equipment', 'Companies', 'firms', 'businesses', 'company', 'corporations', 'industry', 'business', 'manufacturers', 'makers', 'venture', 'industries']
#
# None
# ['AnalyseBuildMicrosoft', 'Contribute', 'contributes', 'encourage', 'reduce', 'benefit', 'promote', 'enhance', 'improve', 'achieve', 'expand', 'accelerate', 'Mining', 'coal', 'mines', 'copper', 'industrial', 'ore', 'mine', 'mineral', 'exploration', 'minerals', 'logging', 'Management', 'financial', 'business', 'managers', 'investment', 'development', 'consulting', 'managing', 'marketing', 'corporate', 'asset', 'Engage', 'engaging', 'encourage', 'engaged', 'pursue', 'participate', 'willing', 'cooperate', 'initiate', 'conduct', 'actively', 'Computer', 'computers', 'software', 'technology', 'pc', 'hardware', 'internet', 'desktop', 'electronic', 'systems', 'computing', 'Data', 'information', 'analysis', 'tracking', 'database', 'system', 'computer', 'statistics', 'systems', 'applications', 'numbers', 'Science', 'sciences', 'physics', 'institute', 'mathematics', 'studies', 'research', 'biology', 'university', 'psychology', 'economics', 'Determine', 'determined', 'whether', 'determining', 'decide', 'examine', 'evaluate', 'assess', 'identify', 'possible', 'deciding']
#
# None
# ...
#
# ['The', 'this', 'part', 'one', 'of', 'same', 'first', 'on', 'its', 'as', 'that', 'Continuous', 'constant', 'continual', 'periodic', 'static', 'rapid', 'linear', 'continuation', 'normal', 'extensive', 'direct', 'Informatics', 'biomedical', 'neuroscience', 'cybernetics', 'sciences', 'bioinformatics', 'microbiology', 'humanities', 'robotics', 'nanotechnology', 'olympiad', 'Grad', 'bm-21', 'grads', 'mrkonjic', 'mrkonjić', 'katyusha', 'ib', 'rocket', '122mm', 'sipovo', 'rockets', 'Programme', 'programmes', 'program', 'programs', 'project', 'bbc', 'development', 'projects', 'funding', 'educational', 'activities', 'Computer', 'computers', 'software', 'technology', 'pc', 'hardware', 'internet', 'desktop', 'electronic', 'systems', 'computing', 'Learning', 'teaching', 'knowledge', 'experience', 'skills', 'learn', 'understanding', 'education', 'educational', 'lessons', 'studying', 'Science', 'sciences', 'physics', 'institute', 'mathematics', 'studies', 'research', 'biology', 'university', 'psychology', 'economics', 'Technology', 'technologies', 'computer', 'tech', 'software', 'systems', 'innovation', 'technological', 'engineering', 'research', 'computing', 'Information', 'data', 'knowledge', 'access', 'provided', 'intelligence', 'source', 'documents', 'web', 'internet', 'provide']
#
# None
# ['UnderstandPursues', 'Requirements', 'requirement', 'standards', 'regulations', 'required', 'rules', 'criteria', 'limits', 'guidelines', 'compliance', 'require', 'Team', 'teams', 'squad', 'football', 'players', 'coach', 'player', 'league', 'season', 'soccer', 'championship', 'Assurance', 'assurances', 'guarantee', 'satisfaction', 'trust', 'guarantees', 'guidance', 'clarity', 'adequate', 'assure', 'assessment', 'External', 'internal', 'structural', 'foreign', 'direct', 'and/or', 'current', 'system', 'affairs', 'budgetary', 'input', 'Quality', 'excellent', 'standards', 'performance', 'good', 'better', 'improve', 'lack', 'product', 'efficiency', 'well', 'Accounting', 'auditing', 'audit', 'financial', 'auditors', 'practices', 'bookkeeping', 'management', 'corporate', 'disclosure', 'firms']
#
# None
# None
# ['South', 'north', 'west', 'east', 'western', 'southern', 'southeast', 'africa', 'korea', 'northern', 'northeast', 'AfricaInstrumentation', 'Telecommunication', 'telecommunications', 'telecoms', 'telecom', 'communications', 'wireless', 'communication', 'telephony', 'infrastructure', 'services', 'provider', 'Competencies', 'competences', 'competence', 'competency', 'self-discipline', 'strengths', 'methodologies', 'qualifications', 'teamwork', 'proficiencies', 'abilities', 'Opportunities', 'opportunity', 'possibilities', 'advantages', 'advantage', 'benefit', 'experience', 'innovation', 'resources', 'development', 'encourage', 'Human', 'animal', 'rights', 'humans', 'animals', 'body', 'nature', 'beings', 'organization', 'scientific', 'common', 'Management', 'financial', 'business', 'managers', 'investment', 'development', 'consulting', 'managing', 'marketing', 'corporate', 'asset', 'Tech', 'technology', 'electronics', 'computer', 'chip', 'big', 'business', 'texas', 'industrial', 'advanced', 'technological', 'Resource', 'resources', 'conservation', 'environment', 'development', 'enterprise', 'natural', 'management', 'energy', 'technology', 'biodiversity', 'Control', 'controls', 'controlled', 'power', 'controlling', 'system', 'security', 'own', 'authority', 'rule', 'forces', 'Electrical', 'mechanical', 'electric', 'electricity', 'machinery', 'components', 'engineering', 'wiring', 'plumbing', 'equipment', 'generator', 'Industrial', 'manufacturing', 'industries', 'sector', 'sectors', 'agricultural', 'construction', 'machinery', 'textile', 'industry', 'mining', 'Graduate', 'undergraduate', 'graduating', 'harvard', 'enrolled', 'graduated', 'college', 'graduates', 'faculty', 'university', 'yale', 'Completed', 'completion', 'completing', 'complete', 'first', 'construction', 'commenced', 'finished', 'later', 'project', 'prior', 'Literacy', 'numeracy', 'education', 'educational', 'illiteracy', 'math', 'curriculum', 'proficiency', 'learners', 'awareness', 'enrollment', 'Programme', 'programmes', 'program', 'programs', 'project', 'bbc', 'development', 'projects', 'funding', 'educational', 'activities', 'Our', 'their', 'my', 'your', 'own', 'we', 'way', 'what', 'good', 'whatever', 'need', 'Computer', 'computers', 'software', 'technology', 'pc', 'hardware', 'internet', 'desktop', 'electronic', 'systems', 'computing', 'Social', 'education', 'political', 'cultural', 'welfare', 'educational', 'reform', 'health', 'public', 'environment', 'environmental', 'Skills', 'skill', 'abilities', 'talents', 'expertise', 'learning', 'ability', 'knowledge', 'experience', 'talent', 'techniques', 'Trainee', 'apprentice', 'full-time', 'part-time', 'janitor', 'technician', 'recruiter', 'trainees', 'paralegal', 'instructor', 'tutor', 'Honours', 'honors', 'honour', 'bestowed', 'knighthood', 'awarded', 'knighted', 'honorary', 'diploma', 'prizes', 'conferred', 'Chemical', 'chemicals', 'biological', 'toxic', 'materials', 'biochemical', 'compounds', 'industrial', 'components', 'nuclear', 'pesticides', 'Mechanical', 'electrical', 'engineering', 'hydraulic', 'mechanics', 'technical', 'hydraulics', 'physics', 'structural', 'components', 'design', 'Structured', 'customized', 'unstructured', 'integrated', 'flexible', 'combining', 'defined', 'structuring', 'hierarchical', 'tailored', 'coherent', 'Marketing', 'advertising', 'business', 'merchandising', 'product', 'management', 'corporate', 'brand', 'company', 'strategy', 'creative', 'Sales', 'retail', 'revenue', 'profit', 'earnings', 'consumer', 'profits', 'product', 'revenues', 'market', 'selling', 'Trainees', 'instructors', 'cadets', 'recruits', 'apprentices', 'sergeants', 'graduates', 'undergraduates', 'tutors', 'interns', 'recruiters', 'Bachelor', 'doctorate', 'degree', 'bachelors', 'graduate', 'ph.d.', 'b.a.', 'undergraduate', 'graduated', 'phd', 'diploma', 'Resources', 'resource', 'energy', 'environment', 'development', 'needs', 'natural', 'expertise', 'provide', 'infrastructure', 'reserves', 'Arts', 'art', 'academy', 'sci ...
#
# None
# ['Chemical', 'chemicals', 'biological', 'toxic', 'materials', 'biochemical', 'compounds', 'industrial', 'components', 'nuclear', 'pesticides', 'Graduate', 'undergraduate', 'graduating', 'harvard', 'enrolled', 'graduated', 'college', 'graduates', 'faculty', 'university', 'yale', 'Qualification', 'qualifying', 'qualify', 'qualified', 'qualifiers', 'play-off', 'qualifications', 'champions', 'uefa', 'tournament', 'championship', 'Programme', 'programmes', 'program', 'programs', 'project', 'bbc', 'development', 'projects', 'funding', 'educational', 'activities', 'Must', 'should', 'cannot', 'would', 'need', 'can', 'will', 'not', 'could', 'be', 'come', 'Engineering', 'sciences', 'technology', 'technical', 'science', 'mechanical', 'engineers', 'institute', 'mathematics', 'biomedical', 'physics', 'IndustryStellenbosch']
#
# None
# ['South', 'north', 'west', 'east', 'western', 'southern', 'southeast', 'africa', 'korea', 'northern', 'northeast', 'AfricaWholesale', 'Institution', 'institutions', 'society', 'institute', 'established', 'private', 'university', 'foundation', 'academic', 'education', 'educational', 'Group', 'groups', 'based', 'members', 'organization', 'led', 'which', 'formed', 'alliance', 'joined', 'called', 'Industrial', 'manufacturing', 'industries', 'sector', 'sectors', 'agricultural', 'construction', 'machinery', 'textile', 'industry', 'mining', 'Digital', 'electronic', 'analog', 'video', 'audio', 'multimedia', 'computer', 'wireless', 'interactive', 'internet', 'computers', 'Education', 'educational', 'schools', 'teaching', 'curriculum', 'programs', 'social', 'health', 'school', 'academic', 'welfare', 'Human', 'animal', 'rights', 'humans', 'animals', 'body', 'nature', 'beings', 'organization', 'scientific', 'common', 'Marketing', 'advertising', 'business', 'merchandising', 'product', 'management', 'corporate', 'brand', 'company', 'strategy', 'creative', 'Business', 'industry', 'companies', 'businesses', 'marketing', 'company', 'corporate', 'financial', 'market', 'investment', 'management', 'Perform', 'performed', 'performing', 'performs', 'participate', 'live', 'undergo', 'dance', 'sing', 'required', 'able', 'Administration', 'government', 'policy', 'bush', 'congress', 'officials', 'clinton', 'office', 'department', 'federal', 'washington', 'Execute', 'executing', 'executed', 'executes', 'execution', 'accountable', 'instructions', 'respond', 'implement', 'proceed', 'faithfully', 'Management', 'financial', 'business', 'managers', 'investment', 'development', 'consulting', 'managing', 'marketing', 'corporate', 'asset', 'Required', 'require', 'requires', 'requiring', 'necessary', 'requirement', 'requirements', 'allow', 'needed', 'provide', 'must', 'Psychology', 'sociology', 'philosophy', 'anthropology', 'biology', 'psychiatry', 'neuroscience', 'science', 'professor', 'studies', 'economics', 'Resource', 'resources', 'conservation', 'environment', 'development', 'enterprise', 'natural', 'management', 'energy', 'technology', 'biodiversity', 'Project', 'projects', 'development', 'program', 'plan', 'construction', 'plans', 'work', 'initiative', 'part', 'build', 'Retail', 'sales', 'retailers', 'consumer', 'stores', 'market', 'retailing', 'wholesale', 'store', 'businesses', 'retailer']
#
# None
# ['Commerce', 'trade', 'department', 'transportation', 'tourism', 'finance', 'industry', 'affairs', 'agriculture', 'business', 'bureau', 'Industrial', 'manufacturing', 'industries', 'sector', 'sectors', 'agricultural', 'construction', 'machinery', 'textile', 'industry', 'mining', 'Responsibilities', 'duties', 'responsibility', 'obligations', 'tasks', 'matters', 'fulfill', 'priorities', 'delegated', 'objectives', 'entrusted', 'Business', 'industry', 'companies', 'businesses', 'marketing', 'company', 'corporate', 'financial', 'market', 'investment', 'management', 'Finance', 'banking', 'foreign', 'minister', 'financial', 'commerce', 'investment', 'reform', 'government', 'fund', 'affairs', 'Management', 'financial', 'business', 'managers', 'investment', 'development', 'consulting', 'managing', 'marketing', 'corporate', 'asset', 'Systems', 'system', 'technologies', 'equipment', 'technology', 'software', 'computer', 'devices', 'components', 'communications', 'communication', 'Deliver', 'delivering', 'delivered', 'provide', 'carry', 'delivers', 'promised', 'bring', 'send', 'promise', 'produce', 'Computer', 'computers', 'software', 'technology', 'pc', 'hardware', 'internet', 'desktop', 'electronic', 'systems', 'computing', 'Psychology', 'sociology', 'philosophy', 'anthropology', 'biology', 'psychiatry', 'neuroscience', 'science', 'professor', 'studies', 'economics', 'Science', 'sciences', 'physics', 'institute', 'mathematics', 'studies', 'research', 'biology', 'university', 'psychology', 'economics', 'Information', 'data', 'knowledge', 'access', 'provided', 'intelligence', 'source', 'documents', 'web', 'internet', 'provide', 'Accounting', 'auditing', 'audit', 'financial', 'auditors', 'practices', 'bookkeeping', 'management', 'corporate', 'disclosure', 'firms', 'ParticipationMathsActuarial', 'Science', 'sciences', 'physics', 'institute', 'mathematics', 'studies', 'research', 'biology', 'university', 'psychology', 'economics', 'Participate', 'participating', 'attend', 'join', 'participation', 'organize', 'participated', 'compete', 'engage', 'enter', 'continue']
#
# None
# ['GqeberhaInternational', 'Skills', 'skill', 'abilities', 'talents', 'expertise', 'learning', 'ability', 'knowledge', 'experience', 'talent', 'techniques', 'Durban', 'johannesburg', 'pretoria', 'bloemfontein', 'pietermaritzburg', 'galle', 'polokwane', 'newlands', 'cape', 'auckland', 'christchurch', 'Group', 'groups', 'based', 'members', 'organization', 'led', 'which', 'formed', 'alliance', 'joined', 'called', 'The', 'this', 'part', 'one', 'of', 'same', 'first', 'on', 'its', 'as', 'that', 'Adapting', 'adapt', 'evolving', 'devising', 'designing', 'innovating', 'adjusting', 'inventing', 'integrating', 'perfecting', 'experimenting', 'Business', 'industry', 'companies', 'businesses', 'marketing', 'company', 'corporate', 'financial', 'market', 'investment', 'management', 'Chain', 'chains', 'stores', 'store', 'supermarket', 'grocery', 'retail', 'retailer', 'restaurants', 'shop', 'supermarkets', 'Quantitative', 'qualitative', 'empirical', 'analysis', 'methodology', 'analytical', 'methods', 'analyses', 'behavioral', 'descriptive', 'theoretical', 'Shoprite', 'wegmans', 'dfs', 'safeway', 'fujisankei', 'funai', 'takefuji', 'lpga', 'crowne', 'mizuno', 'maurier', 'Trade', 'export', 'economic', 'trading', 'commerce', 'cooperation', 'exports', 'industry', 'wto', 'market', 'exchange', 'Management', 'financial', 'business', 'managers', 'investment', 'development', 'consulting', 'managing', 'marketing', 'corporate', 'asset', 'Enterprising', 'industrious', 'resourceful', 'adventurous', 'hardworking', 'astute', 'hard-working', 'adventuresome', 'skilful', 'inquisitive', 'headstrong', 'Supply', 'supplies', 'fuel', 'electricity', 'demand', 'shortage', 'oil', 'capacity', 'food', 'gasoline', 'equipment', 'Companies', 'firms', 'businesses', 'company', 'corporations', 'industry', 'business', 'manufacturers', 'makers', 'venture', 'industries']
#
# ['Theory', 'theories', 'concept', 'evolution', 'hypothesis', 'concepts', 'theoretical', 'notion', 'logic', 'philosophy', 'analysis', 'Accounting', 'auditing', 'audit', 'financial', 'auditors', 'practices', 'bookkeeping', 'management', 'corporate', 'disclosure', 'firms']
#
# ['Danone', 'nestle', 'aventis', "l'oreal", 'wahaha', 'sanofi', 'inbev', 'pepsico', 'novartis', 'interbrew', 'groupe', 'Operations', 'operation', 'unit', 'operating', 'personnel', 'military', 'services', 'command', 'operational', 'units', 'force']

# %%
newdf = pd.DataFrame(columns=["ExtendedTags"])

# %%
newdf["ExtendedTags"] = finaltagls

# %%
newdf["ExtendedTags"][0]
# Out:
# 'South, north, west, east, western, southern, southeast, africa, korea, northern, northeast, AfricaChemical, Institution, institutions, society, institute, established, private, university, foundation, academic, education, educational, Digital, electronic, analog, video, audio, multimedia, computer, wireless, interactive, internet, computers, Energy, resources, gas, renewable, natural, petroleum, electricity, oil, power, development, fuel, Metals, minerals, copper, commodities, ferrous, commodity, ores, aluminium, alloys, chemicals, zinc, Mining, coal, mines, copper, industrial, ore, mine, mineral, exploration, minerals, logging, Eng, fra, aus, capt, saracens, leicester, rsa, esp, harlequins, /, gareth, Engineering, sciences, technology, technical, science, mechanical, engineers, institute, mathematics, biomedical, physics, Tertiary, secondary, schooling, post-secondary, vocational, quaternary, colleges, undergraduate, pupils, education, university-level'

# %%
newdf.shape
# Out:
# (198, 1)

# %%
prompt_words = ['engineering', 'chemical', 'marketing', 'Limpopo']

all_sentences = []

for column in extjobs.columns:
    for index, sentence in enumerate(extjobs[column]):
        tokens = nlp(sentence.lower())
        tokens = [token.text for token in tokens if not token.is_punct and not token.is_stop]
        doc = nlp(" ".join(tokens))
        
        similarities = [doc.similarity(nlp(word.lower())) for word in prompt_words]
        
        max_similarity = max(similarities)
        all_sentences.append((sentence, max_similarity, index))
        
sorted_sentences = sorted(all_sentences, key=lambda x: x[1], reverse=True)

top_10_indexes = [item[2] for item in sorted_sentences[:10]]

print("Indexes of top 10 sentences:", top_10_indexes)
# Out:
# C:\Users\Sachin\AppData\Local\Temp\ipykernel_16144\2011912737.py:18: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   similarities = [doc.similarity(nlp(word.lower())) for word in prompt_words]
# Indexes of top 10 sentences: [77, 124, 15, 15, 84, 153, 15, 84, 153, 15]

# %%
prompt_words = ['engineering', 'chemical', 'marketing']
extjobs.iloc[top_10_indexes]
# Out:
#                                     companyName             jobType  \
# 8                           University of Venda          Internship
# 55  Limpopo Department of Sport, Arts & Culture          Internship
# 15                                        Sasol  Graduate programme
# 15                                        Sasol  Graduate programme
# 15                                         ABSA          Internship
# 84              National Credit Regulator (NCR)          Internship
# 15                                        Sasol  Graduate programme
# 15                                         ABSA          Internship
# 84              National Credit Regulator (NCR)          Internship
# 15                                        Sasol  Graduate programme
#
#       location                               position  \
# 8      Limpopo              Internship Programme 2023
# 55     Limpopo              Internship Programme 2023
# 15  Mpumalanga    Engineering Graduate Programme 2023
# 15  Mpumalanga    Engineering Graduate Programme 2023
# 15     Gauteng     Graduate Internship Programme 2023
# 84     Gauteng  Procurement Internship Programme 2023
# 15  Mpumalanga    Engineering Graduate Programme 2023
# 15     Gauteng     Graduate Internship Programme 2023
# 84     Gauteng  Procurement Internship Programme 2023
# 15  Mpumalanga    Engineering Graduate Programme 2023
#
#                                           description  \
# 8   The of University of Venda invites application...
# 55  Workplace experience posts for unemployed grad...
# 15  This role is for a position in the graduate de...
# 15  This role is for a position in the graduate de...
# 15  Position Title: Risk Management and Dispute Re...
# 84  Duration: 12 months contract\nStipend: R5391.0...
# 15  This role is for a position in the graduate de...
# 15  Position Title: Risk Management and Dispute Re...
# 84  Duration: 12 months contract\nStipend: R5391.0...
# 15  This role is for a position in the graduate de...
#
#                                           Aggregation  \
# 8   South, AfricaWholesale, Institution, Group, In...
# 55  South, Marketing, AfricaSkills, Trainee, Gradu...
# 15  Geology, Chemical, Trainee, Industrial, Gradua...
# 15  Geology, Chemical, Trainee, Industrial, Gradua...
# 15  Geology, Chemical, Trainee, Industrial, Gradua...
# 84  Geology, Chemical, Trainee, Industrial, Gradua...
# 15  Geology, Chemical, Trainee, Industrial, Gradua...
# 15  Geology, Chemical, Trainee, Industrial, Gradua...
# 84  Geology, Chemical, Trainee, Industrial, Gradua...
# 15  Geology, Chemical, Trainee, Industrial, Gradua...
#
#                                          ExtendedTags
# 8   South, north, west, east, western, southern, s...
# 55  South, north, west, east, western, southern, s...
# 15  Geology, mineralogy, zoology, geography, archa...
# 15  Geology, mineralogy, zoology, geography, archa...
# 15  Geology, mineralogy, zoology, geography, archa...
# 84  Geology, mineralogy, zoology, geography, archa...
# 15  Geology, mineralogy, zoology, geography, archa...
# 15  Geology, mineralogy, zoology, geography, archa...
# 84  Geology, mineralogy, zoology, geography, archa...
# 15  Geology, mineralogy, zoology, geography, archa...

# %%
#Outputing the final extdf
extjobs.to_csv("synthesized.csv")

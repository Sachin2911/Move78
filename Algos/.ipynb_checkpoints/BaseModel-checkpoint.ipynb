# %%
# Libraries
import numpy as np
import pandas as pd
import spacy

nlp = spacy.load('en_core_web_md')
synth = "synthesized.csv"

extjobs = pd.read_csv(synth, index_col=0)

prompt_words = ['engineering', 'chemical', 'marketing', 'Limpopo']

all_sentences = []

for column in extjobs.columns:
    for index, sentence in enumerate(extjobs[column]):
        if pd.notna(sentence):  # Check if sentence is not NaN
            tokens = nlp(str(sentence).lower())
            tokens = [token.text for token in tokens if not token.is_punct and not token.is_stop]
            doc = nlp(" ".join(tokens))
        
            similarities = [doc.similarity(nlp(word.lower())) for word in prompt_words]
        
            max_similarity = max(similarities)
            all_sentences.append((sentence, max_similarity, index))
        
sorted_sentences = sorted(all_sentences, key=lambda x: x[1], reverse=True)

top_10_indexes = [item[2] for item in sorted_sentences[:10]]

print("Indexes of top 10 sentences:", top_10_indexes)
# Out:
# C:\Users\Sachin\AppData\Local\Temp\ipykernel_8668\190925055.py:22: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   similarities = [doc.similarity(nlp(word.lower())) for word in prompt_words]
# Indexes of top 10 sentences: [77, 124, 15, 15, 84, 153, 15, 84, 153, 15]

# %%
extjobs.iloc[top_10_indexes]
# Out:
#                                     companyName             jobType  \
# 8                           University of Venda          Internship
# 55  Limpopo Department of Sport, Arts & Culture          Internship
# 15                                        Sasol  Graduate programme
# 15                                        Sasol  Graduate programme
# 15                                         ABSA          Internship
# 84              National Credit Regulator (NCR)          Internship
# 15                                        Sasol  Graduate programme
# 15                                         ABSA          Internship
# 84              National Credit Regulator (NCR)          Internship
# 15                                        Sasol  Graduate programme
#
#       location                               position  \
# 8      Limpopo              Internship Programme 2023
# 55     Limpopo              Internship Programme 2023
# 15  Mpumalanga    Engineering Graduate Programme 2023
# 15  Mpumalanga    Engineering Graduate Programme 2023
# 15     Gauteng     Graduate Internship Programme 2023
# 84     Gauteng  Procurement Internship Programme 2023
# 15  Mpumalanga    Engineering Graduate Programme 2023
# 15     Gauteng     Graduate Internship Programme 2023
# 84     Gauteng  Procurement Internship Programme 2023
# 15  Mpumalanga    Engineering Graduate Programme 2023
#
#                                           description  \
# 8   The of University of Venda invites application...
# 55  Workplace experience posts for unemployed grad...
# 15  This role is for a position in the graduate de...
# 15  This role is for a position in the graduate de...
# 15  Position Title: Risk Management and Dispute Re...
# 84  Duration: 12 months contract\nStipend: R5391.0...
# 15  This role is for a position in the graduate de...
# 15  Position Title: Risk Management and Dispute Re...
# 84  Duration: 12 months contract\nStipend: R5391.0...
# 15  This role is for a position in the graduate de...
#
#                                           Aggregation  \
# 8   South, AfricaWholesale, Institution, Group, In...
# 55  South, Marketing, AfricaSkills, Trainee, Gradu...
# 15  Geology, Chemical, Trainee, Industrial, Gradua...
# 15  Geology, Chemical, Trainee, Industrial, Gradua...
# 15  Geology, Chemical, Trainee, Industrial, Gradua...
# 84  Geology, Chemical, Trainee, Industrial, Gradua...
# 15  Geology, Chemical, Trainee, Industrial, Gradua...
# 15  Geology, Chemical, Trainee, Industrial, Gradua...
# 84  Geology, Chemical, Trainee, Industrial, Gradua...
# 15  Geology, Chemical, Trainee, Industrial, Gradua...
#
#                                          ExtendedTags
# 8   South, north, west, east, western, southern, s...
# 55  South, north, west, east, western, southern, s...
# 15  Geology, mineralogy, zoology, geography, archa...
# 15  Geology, mineralogy, zoology, geography, archa...
# 15  Geology, mineralogy, zoology, geography, archa...
# 84  Geology, mineralogy, zoology, geography, archa...
# 15  Geology, mineralogy, zoology, geography, archa...
# 15  Geology, mineralogy, zoology, geography, archa...
# 84  Geology, mineralogy, zoology, geography, archa...
# 15  Geology, mineralogy, zoology, geography, archa...

# %%
import spacy
import pandas as pd

def get_top_sentence_indexes(prompt):
    nlp = spacy.load('en_core_web_md')
    synth = "synthesized.csv"

    extjobs = pd.read_csv(synth, index_col=0)

    prompt_words = nlp(prompt.lower())
    prompt_words = [token.text for token in prompt_words if not token.is_punct and not token.is_stop]

    all_sentences = []

    for column in extjobs.columns:
        for index, sentence in enumerate(extjobs[column]):
            if pd.notna(sentence):  # Check if sentence is not NaN
                tokens = nlp(str(sentence).lower())
                tokens = [token.text for token in tokens if not token.is_punct and not token.is_stop]
                doc = nlp(" ".join(tokens))

                similarities = [doc.similarity(nlp(word.lower())) for word in prompt_words]

                max_similarity = max(similarities)
                all_sentences.append((sentence, max_similarity, index))

    sorted_sentences = sorted(all_sentences, key=lambda x: x[1], reverse=True)
    top_10_indexes = [item[2] for item in sorted_sentences[:10]]

    return top_10_indexes

# %%
prompt = "I am looking for chemical engineering positions"
indexes = get_top_sentence_indexes(prompt)
print("Indexes of top 10 sentences:", indexes)
# Out:
# C:\Users\Sachin\AppData\Local\Temp\ipykernel_8668\1026483768.py:22: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   similarities = [doc.similarity(nlp(word.lower())) for word in prompt_words]
# Indexes of top 10 sentences: [15, 84, 153, 15, 84, 153, 15, 7, 76, 145]

# %%
extjobs.iloc[indexes]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 extjobs[indexes]
#
# File ~\.conda\envs\MachineLearning\lib\site-packages\pandas\core\frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File ~\.conda\envs\MachineLearning\lib\site-packages\pandas\core\indexes\base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
#    6074     # GH 42790 - Preserve name from an Index
#
# File ~\.conda\envs\MachineLearning\lib\site-packages\pandas\core\indexes\base.py:6130, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6128     if use_interval_msg:
#    6129         key = list(key)
# -> 6130     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6132 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6133 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Int64Index([15, 84, 153, 15, 84, 153, 15, 7, 76, 145], dtype='int64')] are in the [columns]"
